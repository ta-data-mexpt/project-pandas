# %%
# !pip install python-oauth2

# %%
import requests
import time
import oauth2 as oauth2
import json
import pandas as pd

# %%
access_token='eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyMzkzQzQiLCJzdWIiOiI2WldWWFIiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJhY3QgcnNldCBybG9jIHJ3ZWkgcmhyIHJudXQgcnBybyByc2xlIiwiZXhwIjoxNjcyMzcyODI3LCJpYXQiOjE2Njk3ODA4Mjd9.JgqNMJA2ExHGTBUSygJCRCbV8hdg6owLyWmh18KNYwQ'
user_id='6ZWVXR'

# %%
activity_request=requests.get('https://api.fitbit.com/1/user/'+user_id+'/activities/steps/date/2022-04-01/1y.json', headers={'Authorization': 'Bearer ' + access_token})

# %%
print(activity_request.status_code)
steps=activity_request.json()['activities-steps']
flattened_steps= pd.json_normalize(steps)
steps_table= pd.DataFrame(flattened_steps)
pd.set_option('display.max_rows', 4000)
steps_table
# Out:
# 200
#        dateTime  value
# 0    2021-04-02      0
# 1    2021-04-03      0
# 2    2021-04-04      0
# 3    2021-04-05   3772
# 4    2021-04-06   6900
# 5    2021-04-07   3283
# 6    2021-04-08   3797
# 7    2021-04-09   4705
# 8    2021-04-10      0
# 9    2021-04-11      0
# 10   2021-04-12   4383
# 11   2021-04-13   6382
# 12   2021-04-14   5421
# 13   2021-04-15   3159
# 14   2021-04-16   5650
# 15   2021-04-17      0
# 16   2021-04-18      0
# 17   2021-04-19   5541
# 18   2021-04-20   3776
# 19   2021-04-21   2759
# 20   2021-04-22   5991
# 21   2021-04-23   3983
# 22   2021-04-24      0
# 23   2021-04-25      0
# 24   2021-04-26   5749
# 25   2021-04-27   5343
# 26   2021-04-28   2693
# 27   2021-04-29   5614
# 28   2021-04-30   5144
# 29   2021-05-01      0
# 30   2021-05-02      0
# 31   2021-05-03   4342
# 32   2021-05-04   4482
# 33   2021-05-05   3155
# 34   2021-05-06   4575
# 35   2021-05-07   5005
# 36   2021-05-08      0
# 37   2021-05-09      0
# ...

# %%
df_steps=pd.DataFrame()
access_token='eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyMzkzQzQiLCJzdWIiOiI2WldWWFIiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJhY3QgcnNldCBybG9jIHJ3ZWkgcmhyIHJudXQgcnBybyByc2xlIiwiZXhwIjoxNjcyMzcyODI3LCJpYXQiOjE2Njk3ODA4Mjd9.JgqNMJA2ExHGTBUSygJCRCbV8hdg6owLyWmh18KNYwQ'
user_id='6ZWVXR'
for i in range (21,23):
    activity_request=requests.get('https://api.fitbit.com/1/user/'+user_id+f'/activities/steps/date/20{i}-12-01/1y.json', headers={'Authorization': 'Bearer ' + access_token})
    steps=activity_request.json()['activities-steps']
    flattened_steps= pd.json_normalize(steps)
    steps_table= pd.DataFrame(flattened_steps)
    df_steps=pd.concat([df_steps,steps_table])

# %%
df_steps = df_steps.rename(columns={'dateTime': 'Date', 'value': 'Steps'})
df_steps.reset_index(inplace=True, drop=True)
df_steps
# Out:
#            Date  Steps
# 0    2020-12-02   9580
# 1    2020-12-03   3818
# 2    2020-12-04   2029
# 3    2020-12-05      0
# 4    2020-12-06      0
# 5    2020-12-07   7135
# 6    2020-12-08   3686
# 7    2020-12-09      0
# 8    2020-12-10   1816
# 9    2020-12-11   8217
# 10   2020-12-12   6897
# 11   2020-12-13      0
# 12   2020-12-14   2396
# 13   2020-12-15   4616
# 14   2020-12-16      0
# 15   2020-12-17   3086
# 16   2020-12-18   1153
# 17   2020-12-19      0
# 18   2020-12-20   8019
# 19   2020-12-21   4078
# 20   2020-12-22      0
# 21   2020-12-23   2090
# 22   2020-12-24   7334
# 23   2020-12-25      0
# 24   2020-12-26      0
# 25   2020-12-27      0
# 26   2020-12-28      0
# 27   2020-12-29      0
# 28   2020-12-30      0
# 29   2020-12-31      0
# 30   2021-01-01      0
# 31   2021-01-02      0
# 32   2021-01-03      0
# 33   2021-01-04      0
# 34   2021-01-05      0
# 35   2021-01-06   3724
# 36   2021-01-07   4313
# 37   2021-01-08   5188
# 38   2021-01-09      0
# ...

# %%
distance_request=requests.get('https://api.fitbit.com/1/user/'+user_id+'/activities/distance/date/2020-12-02/2022-12-01.json', headers={'Authorization': 'Bearer ' + access_token})

# %%
print(distance_request.status_code)
distancia=distance_request.json()['activities-distance']
flattened_distance= pd.json_normalize(distancia)
distance_table= pd.DataFrame(flattened_distance)
distance_table = distance_table.rename(columns={'dateTime': 'Fecha', 'value': 'Distancia'})
distance_table
# Out:
# 200
#           Fecha            Distancia
# 0    2020-12-02              7.10861
# 1    2020-12-03              2.44533
# 2    2020-12-04              1.17035
# 3    2020-12-05                  0.0
# 4    2020-12-06                  0.0
# 5    2020-12-07              5.41168
# 6    2020-12-08              2.32945
# 7    2020-12-09                  0.0
# 8    2020-12-10                0.828
# 9    2020-12-11              6.22349
# 10   2020-12-12              4.27039
# 11   2020-12-13                  0.0
# 12   2020-12-14   1.2215399999999998
# 13   2020-12-15   3.5728199999999997
# 14   2020-12-16                  0.0
# 15   2020-12-17              1.96877
# 16   2020-12-18              0.63152
# 17   2020-12-19                  0.0
# 18   2020-12-20    6.296749999999999
# 19   2020-12-21              2.75704
# 20   2020-12-22                  0.0
# 21   2020-12-23              1.09903
# 22   2020-12-24              5.04493
# 23   2020-12-25                  0.0
# ...

# %%
calories_request=requests.get('https://api.fitbit.com/1/user/'+user_id+'/activities/calories/date/2020-12-02/2022-12-01.json', headers={'Authorization': 'Bearer ' + access_token})

# %%
print(calories_request.status_code)
calorias=calories_request.json()['activities-calories']
flattened_calories= pd.json_normalize(calorias)
calories_table= pd.DataFrame(flattened_calories)
calories_table = calories_table.rename(columns={'dateTime': 'Fecha', 'value': 'Calories'})
calories_table
# Out:
# 200
#           Fecha Calories
# 0    2020-12-02     1904
# 1    2020-12-03     1516
# 2    2020-12-04     1604
# 3    2020-12-05     1239
# 4    2020-12-06     1240
# 5    2020-12-07     1807
# 6    2020-12-08     1523
# 7    2020-12-09     1237
# 8    2020-12-10     1527
# 9    2020-12-11     1709
# 10   2020-12-12     1675
# 11   2020-12-13     1232
# 12   2020-12-14     1554
# 13   2020-12-15     1521
# 14   2020-12-16     1231
# 15   2020-12-17     1438
# 16   2020-12-18     1486
# 17   2020-12-19     1236
# 18   2020-12-20     1761
# 19   2020-12-21     1521
# 20   2020-12-22     1232
# 21   2020-12-23     1505
# 22   2020-12-24     1673
# 23   2020-12-25     1235
# 24   2020-12-26     1235
# 25   2020-12-27     1235
# 26   2020-12-28     1235
# 27   2020-12-29     1230
# 28   2020-12-30     1228
# 29   2020-12-31     1228
# 30   2021-01-01     1227
# 31   2021-01-02     1227
# 32   2021-01-03     1227
# 33   2021-01-04     1226
# 34   2021-01-05     1226
# ...

# %%
final_table=pd.concat([df_steps, distance_table, calories_table], axis=1)


final_table
# Out:
#            Date  Steps       Fecha            Distancia       Fecha Calories
# 0    2020-12-02   9580  2020-12-02              7.10861  2020-12-02     1904
# 1    2020-12-03   3818  2020-12-03              2.44533  2020-12-03     1516
# 2    2020-12-04   2029  2020-12-04              1.17035  2020-12-04     1604
# 3    2020-12-05      0  2020-12-05                  0.0  2020-12-05     1239
# 4    2020-12-06      0  2020-12-06                  0.0  2020-12-06     1240
# 5    2020-12-07   7135  2020-12-07              5.41168  2020-12-07     1807
# 6    2020-12-08   3686  2020-12-08              2.32945  2020-12-08     1523
# 7    2020-12-09      0  2020-12-09                  0.0  2020-12-09     1237
# 8    2020-12-10   1816  2020-12-10                0.828  2020-12-10     1527
# 9    2020-12-11   8217  2020-12-11              6.22349  2020-12-11     1709
# 10   2020-12-12   6897  2020-12-12              4.27039  2020-12-12     1675
# ...

# %%
final_table.drop(['Fecha'], axis=1, inplace=True)

# %%
final_table
# Out:
#            Date  Steps            Distancia Calories
# 0    2020-12-02   9580              7.10861     1904
# 1    2020-12-03   3818              2.44533     1516
# 2    2020-12-04   2029              1.17035     1604
# 3    2020-12-05      0                  0.0     1239
# 4    2020-12-06      0                  0.0     1240
# 5    2020-12-07   7135              5.41168     1807
# 6    2020-12-08   3686              2.32945     1523
# 7    2020-12-09      0                  0.0     1237
# 8    2020-12-10   1816                0.828     1527
# 9    2020-12-11   8217              6.22349     1709
# 10   2020-12-12   6897              4.27039     1675
# 11   2020-12-13      0                  0.0     1232
# 12   2020-12-14   2396   1.2215399999999998     1554
# 13   2020-12-15   4616   3.5728199999999997     1521
# 14   2020-12-16      0                  0.0     1231
# 15   2020-12-17   3086              1.96877     1438
# 16   2020-12-18   1153              0.63152     1486
# ...

# %%
final_table.to_csv('Table_Summary.csv')

# %%
sleep_request=requests.get('https://api.fitbit.com/1.2/user/'+user_id+'/sleep/date/2018-12-02/2019-03-02.json', headers={'Authorization': 'Bearer ' + access_token})

# %%
print(sleep_request.status_code)
dormir=sleep_request.json()['sleep']
flattened_sleep= pd.json_normalize(dormir)
sleep_table= pd.DataFrame(flattened_sleep)
# Out:
# 200

# %%
sleep_request1=requests.get('https://api.fitbit.com/1.2/user/'+user_id+'/sleep/date/2019-03-03/2019-06-02.json', headers={'Authorization': 'Bearer ' + access_token})

# %%
dormir1=sleep_request1.json()['sleep']
flattened_sleep1= pd.json_normalize(dormir1)
sleep_table1= pd.DataFrame(flattened_sleep1)

# %%
sleep_request2=requests.get('https://api.fitbit.com/1.2/user/'+user_id+'/sleep/date/2019-06-03/2019-09-02.json', headers={'Authorization': 'Bearer ' + access_token})

# %%
dormir2=sleep_request2.json()['sleep']
flattened_sleep2= pd.json_normalize(dormir2)
sleep_table2= pd.DataFrame(flattened_sleep2)

# %%
final_sleep=pd.concat([sleep_table, sleep_table1, sleep_table2], axis=0)
final_sleep
# Out:
#    dateOfSleep  duration  efficiency                  endTime  infoCode  \
# 0   2019-01-06  15960000          99  2019-01-06T10:01:30.000         1
# 1   2019-01-06   6420000          93  2019-01-06T03:10:30.000         2
# 2   2019-01-05   5340000          93  2019-01-05T19:37:30.000         2
# 3   2019-01-05  17640000          94  2019-01-05T06:48:30.000         0
# 4   2019-01-04  26220000          95  2019-01-04T08:47:30.000         0
# 5   2019-01-03   8220000          95  2019-01-03T18:23:30.000         2
# 6   2019-01-02  50100000          88  2019-01-02T11:17:30.000         0
# 7   2018-12-31  28680000          93  2018-12-31T09:33:30.000         0
# 8   2018-12-30  27660000          97  2018-12-30T10:23:30.000         0
# 9   2018-12-29  26040000          91  2018-12-29T11:21:30.000         0
# 10  2018-12-29  10140000          96  2018-12-29T00:40:30.000         2
# 11  2018-12-27  21960000          96  2018-12-27T09:49:00.000         1
# ...

# %%
final_sleep.columns.get_loc("endTime")
# Out:
# 3

# %%
print(final_sleep.columns.tolist())
# Out:
# ['dateOfSleep', 'duration', 'efficiency', 'endTime', 'infoCode', 'isMainSleep', 'logId', 'logType', 'minutesAfterWakeup', 'minutesAsleep', 'minutesAwake', 'minutesToFallAsleep', 'startTime', 'timeInBed', 'type', 'levels.data', 'levels.summary.asleep.count', 'levels.summary.asleep.minutes', 'levels.summary.awake.count', 'levels.summary.awake.minutes', 'levels.summary.restless.count', 'levels.summary.restless.minutes', 'levels.shortData', 'levels.summary.deep.count', 'levels.summary.deep.minutes', 'levels.summary.deep.thirtyDayAvgMinutes', 'levels.summary.light.count', 'levels.summary.light.minutes', 'levels.summary.light.thirtyDayAvgMinutes', 'levels.summary.rem.count', 'levels.summary.rem.minutes', 'levels.summary.rem.thirtyDayAvgMinutes', 'levels.summary.wake.count', 'levels.summary.wake.minutes', 'levels.summary.wake.thirtyDayAvgMinutes']

# %%
final_sleep.drop(['efficiency', 'endTime', 'infoCode', 'isMainSleep', 'logId', 'logType', 'minutesAfterWakeup', 'startTime', 'timeInBed', 'type', 'levels.data', 'levels.summary.asleep.count', 'levels.summary.awake.count', 'levels.summary.restless.count', 'levels.summary.restless.minutes', 'levels.shortData', 'levels.summary.deep.count', 'levels.summary.deep.thirtyDayAvgMinutes', 'levels.summary.light.count', 'levels.summary.light.thirtyDayAvgMinutes', 'levels.summary.rem.count', 'levels.summary.rem.thirtyDayAvgMinutes', 'levels.summary.wake.count', 'levels.summary.wake.thirtyDayAvgMinutes'], axis=1, inplace=True)

# %%
final_sleep = final_sleep.rename(columns={'levels.summary.asleep.minutes': 'asleep.minutes', 'levels.summary.awake.minutes': 'awake.minutes', 'levels.summary.deep.minutes': 'deep.minutes', 'levels.summary.light.minutes':'light.minutes', 'levels.summary.rem.minutes':'rem.minutes','levels.summary.wake.minutes':'wake.minutes'})

# %%
final_sleep
# Out:
#    dateOfSleep  duration  minutesAsleep  minutesAwake  minutesToFallAsleep  \
# 0   2019-01-06  15960000            263             2                    0
# 1   2019-01-06   6420000             99             8                    0
# 2   2019-01-05   5340000             83             6                    0
# 3   2019-01-05  17640000            252            42                    0
# 4   2019-01-04  26220000            365            72                    0
# 5   2019-01-03   8220000            130             7                    0
# 6   2019-01-02  50100000            710           125                    0
# 7   2018-12-31  28680000            394            84                    0
# 8   2018-12-30  27660000            424            37                    0
# 9   2018-12-29  26040000            340            94                    0
# 10  2018-12-29  10140000            163             6                    0
# ...

# %%
summary_sleep = final_sleep.fillna(0)

# %%
summary_sleep
# Out:
#    dateOfSleep  duration  minutesAsleep  minutesAwake  minutesToFallAsleep  \
# 0   2019-01-06  15960000            263             2                    0
# 1   2019-01-06   6420000             99             8                    0
# 2   2019-01-05   5340000             83             6                    0
# 3   2019-01-05  17640000            252            42                    0
# 4   2019-01-04  26220000            365            72                    0
# 5   2019-01-03   8220000            130             7                    0
# 6   2019-01-02  50100000            710           125                    0
# 7   2018-12-31  28680000            394            84                    0
# 8   2018-12-30  27660000            424            37                    0
# 9   2018-12-29  26040000            340            94                    0
# 10  2018-12-29  10140000            163             6                    0
# ...

# %%
summary_sleep.sort_values(by='dateOfSleep', inplace=True)
summary_sleep
# Out:
#    dateOfSleep  duration  minutesAsleep  minutesAwake  minutesToFallAsleep  \
# 36  2018-12-02  34020000            497            70                    0
# 34  2018-12-03   9900000            153            12                    0
# 35  2018-12-03  24660000            370            41                    0
# 33  2018-12-04  20160000            295            41                    0
# 32  2018-12-05  28260000            402            69                    0
# 31  2018-12-05   1980000             28             1                    4
# 30  2018-12-06  23820000            321            76                    0
# 29  2018-12-06   6060000             92             3                    3
# 28  2018-12-07  27720000            383            79                    0
# 27  2018-12-08  37920000            523           109                    0
# 26  2018-12-09  33720000            500            62                    0
# ...

# %%
summary_sleep.reset_index(inplace=True, drop=True)

# %%
summary_sleep
# Out:
#    dateOfSleep  duration  minutesAsleep  minutesAwake  minutesToFallAsleep  \
# 0   2018-12-02  34020000            497            70                    0
# 1   2018-12-03   9900000            153            12                    0
# 2   2018-12-03  24660000            370            41                    0
# 3   2018-12-04  20160000            295            41                    0
# 4   2018-12-05  28260000            402            69                    0
# 5   2018-12-05   1980000             28             1                    4
# 6   2018-12-06  23820000            321            76                    0
# 7   2018-12-06   6060000             92             3                    3
# 8   2018-12-07  27720000            383            79                    0
# 9   2018-12-08  37920000            523           109                    0
# 10  2018-12-09  33720000            500            62                    0
# ...

# %%
summary_sleep.to_csv('Table_Sleep_Summary.csv')
