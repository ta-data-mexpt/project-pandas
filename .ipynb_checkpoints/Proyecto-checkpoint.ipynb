# %%
import pandas as pd
import numpy as np
from scipy import stats
import re

# %%
data=pd.read_csv('attacks.csv',encoding = "ISO-8859-1")
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.dropna(subset=['Case Number'])
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
d=data.dropna(thresh=10)
d
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
null_cols = d.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Case Number                  1
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
drop_cols =list(null_cols[null_cols > 6000].index)
d = d.drop(drop_cols, axis=1)

# %%
d
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
null_displ = d[(d['Time'].isnull()==True)]
null_displ = null_displ[['Date', 'original order', 'Country', 'Area','Activity','Age', 'Time','Species ']]
null_displ
# Out:
#              Date  original order             Country               Area  \
# 3     08-Jun-2018          6300.0           AUSTRALIA    New South Wales
# 4     04-Jun-2018          6299.0              MEXICO             Colima
# 5     03-Jun-2018          6298.0           AUSTRALIA    New South Wales
# 7     27-May-2018          6296.0                 USA            Florida
# 11    21-May-2018          6292.0                 USA     South Carolina
# ...           ...             ...                 ...                ...
# 6297  Before 1903             6.0           AUSTRALIA  Western Australia
# 6298  Before 1903             5.0           AUSTRALIA  Western Australia
# 6299    1900-1905             4.0                 USA     North Carolina
# 6300    1883-1889             3.0              PANAMA                NaN
# 6301    1845-1853             2.0  CEYLON (SRI LANKA)   Eastern Province
#
#              Activity  Age Time         Species
# ...

# %%
d.groupby(['Species ']).sum()
# Out:
#                                                        Year  original order
# Species
#                                                     11880.0         22082.0
#  "gummy" shark (Rhizoprionodon or Loxodon) 1.2 ...   1961.0          2396.0
#  1.5 m [5'] dusky shark                              1984.0          3401.0
#  6' to 8' shark                                      2016.0          6100.0
#  Blacktip shark, C. maculipinnis. 1.9 m to 2.1 ...   1962.0          2513.0
# ...                                                     ...             ...
# unknown, possibly a white shark                      1950.0          1828.0
# whaler shark                                         1939.0          1518.0
# white shark                                          1964.0          2628.0
# small brown shark                                  2003.0          4537.0
#                                                      4004.0          8879.0
#
# [1549 rows x 2 columns]
