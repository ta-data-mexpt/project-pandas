# %%
import pandas as pd
import numpy as np
import re

# %%
sharks = pd.read_csv('attacks.csv', encoding = "ISO-8859-1")

# %%
sharks.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
nulos_columnas = sharks.isnull().sum()
porcentaje_nulos = nulos_columnas[nulos_columnas > 0]/sharks.shape[0]
porcentaje_nulos
# Out:
# Case Number               0.661704
# Date                      0.755005
# Year                      0.755083
# Type                      0.755161
# Country                   0.756949
# Area                      0.772694
# Location                  0.775998
# Activity                  0.776154
# Name                      0.763169
# Sex                       0.776970
# Age                       0.865062
# Injury                    0.756094
# Fatal (Y/N)               0.775959
# Time                      0.885394
# Species                   0.865335
# Investigator or Source    0.755666
# pdf                       0.755005
# href formula              0.755044
# href                      0.755005
# Case Number.1             0.755005
# Case Number.2             0.755005
# original order            0.754733
# Unnamed: 22               0.999961
# Unnamed: 23               0.999922
# dtype: float64

# %%
nulos_filas=sharks.isnull().sum(axis = 1)
porcentaje_nulos_filas = nulos_filas[nulos_filas > 0]/sharks.shape[1]
porcentaje_nulos_filas
# Out:
# 0        0.083333
# 1        0.125000
# 2        0.125000
# 3        0.166667
# 4        0.166667
#            ...
# 25718    1.000000
# 25719    1.000000
# 25720    1.000000
# 25721    1.000000
# 25722    0.958333
# Length: 25723, dtype: float64

# %%
columnas_eliminar = porcentaje_nulos[porcentaje_nulos>0.90].index
columnas_eliminar
# Out:
# Index(['Unnamed: 22', 'Unnamed: 23'], dtype='object')

# %%
sharks.drop(columns = columnas_eliminar, inplace = True)

# %%
sharks.shape
# Out:
# (25723, 22)

# %%
sharks.isnull().sum().sort_values()
# Out:
# Case Number               17021
# original order            19414
# Case Number.1             19421
# href                      19421
# pdf                       19421
# Date                      19421
# Case Number.2             19421
# href formula              19422
# Year                      19423
# Type                      19425
# Investigator or Source    19438
# Injury                    19449
# Country                   19471
# Name                      19631
# Area                      19876
# Fatal (Y/N)               19960
# Location                  19961
# Activity                  19965
# Sex                       19986
# Age                       22252
# Species                   22259
# Time                      22775
# dtype: int64

# %%
sharks = sharks.dropna(how='all',axis=0)

# %%
sharks.shape
# Out:
# (8703, 22)

# %%
sharks.reset_index(drop=True, inplace=True)

# %%
nulos_filas=sharks.isnull().sum(axis = 1)
porcentaje_nulos_filas = nulos_filas[nulos_filas > 0]/sharks.shape[1]
porcentaje_nulos_filas
# Out:
# 1       0.045455
# 2       0.045455
# 3       0.090909
# 4       0.090909
# 5       0.136364
#           ...
# 8698    0.954545
# 8699    0.954545
# 8700    0.954545
# 8701    0.954545
# 8702    0.954545
# Length: 7281, dtype: float64

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
sharks.shape
# Out:
# (8703, 22)

# %%
sharks
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 8698           0          NaN     NaN         NaN        NaN              NaN
# 8699           0          NaN     NaN         NaN        NaN              NaN
# 8700           0          NaN     NaN         NaN        NaN              NaN
# 8701           0          NaN     NaN         NaN        NaN              NaN
# 8702          xx          NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
sharks.drop(sharks[sharks['Case Number'] == '0'].index, inplace = True)

# %%
sharks.shape
# Out:
# (6303, 22)

# %%
sharks.drop(sharks[sharks['Case Number'] == 'xx'].index, inplace = True)

# %%
sharks.shape
# Out:
# (6302, 22)

# %%
sharks.drop(columns=['href'], inplace = True)

# %%
sharks.shape
# Out:
# (6302, 21)

# %%
sharks
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks['Type'].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
sharks['Time'].isnull().sum()
# Out:
# 3354

# %%
sharks['Type'] = sharks['Type'].fillna('Unprovoked')

# %%
salidas = {'Unprovoked':['Unprovoked','Questionable', 'Boatomg', 'Sea Disaster'],
          'Provoked':['Provoked', 'Invalid', 'Boating', 'Boat']}

# %%
def simplify_drive(actual):
    try:
        llaves = [key for key, val in salidas.items() if actual in val]

        return llaves[0]
    except:
        print(actual)

# %%
sharks['Type'] = sharks['Type'].apply(simplify_drive)

# %%
sharks['Type'].value_counts()
# Out:
# Unprovoked    4841
# Provoked      1461
# Name: Type, dtype: int64

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
sharks['Fatal (Y/N)'].isnull().sum()
# Out:
# 539

# %%
sharks['Fatal (Y/N)'] = sharks['Fatal (Y/N)'].fillna('N')

# %%
salidas = {'N':['N',' N', 'M', '2017', 'No', 'UNKNOW'],
          'Y':['Y', 'y']}

# %%
sharks['Fatal (Y/N)'].isnull().sum()
# Out:
# 0

# %%
def simplify_drive(actual):
    try:
        llaves = [key for key, val in salidas.items() if actual in val]

        return llaves[0]
    except:
        print(actual)

# %%
sharks['Fatal (Y/N)'] = sharks['Fatal (Y/N)'].apply(simplify_drive)

# %%
sharks.to_csv('pruba.csv')

# %%
sharks['Name'].value_counts()
# Out:
# male                               550
# female                              97
# boy                                 23
# 2 males                             16
# boat                                14
#                                   ...
# Jeremiah Wyche                       1
# Frederico Nóbrega (aka Derico)       1
# Joo Whan Hong                        1
# Alton Cicero da Silva                1
# Jules Patterson                      1
# Name: Name, Length: 5230, dtype: int64

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
columnas_borrar=['Name', 'Age', 'Time', 'Species ', 'pdf', 'Case Number.2']

# %%
sharks.drop(columns = columnas_borrar, inplace = True)

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Injury', 'Fatal (Y/N)', 'Investigator or Source',
#        'href formula', 'Case Number.1', 'original order'],
#       dtype='object')

# %%
sharks[sharks['Case Number'].isnull()==True]
# Out:
#      Case Number                  Date    Year      Type Country     Area  \
# 5488         NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida
#
#                           Location Activity Sex   \
# 5488  Fort Pierce, St Lucie County  Fishing    M
#
#                                                  Injury Fatal (Y/N)  \
# 5488  Lacerations to leg from hooked shark PROVOKED ...           N
#
#               Investigator or Source  \
# 5488  Muncie Evening Press, 8/6/1913
#
#                                            href formula Case Number.1  \
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R
#
#       original order
# 5488           815.0

# %%
sharks.iloc[5488, sharks.columns.get_loc('Case Number')] = '1905.09.06'

# %%
sharks.drop(columns = ['Case Number.1'], inplace = True)

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Injury', 'Fatal (Y/N)', 'Investigator or Source',
#        'href formula', 'original order'],
#       dtype='object')

# %%
sharks
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0    Provoked                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0    Provoked                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
def date(actual):
    actual=actual.replace('Reported','')
    actual=actual.replace('Between','')
    actual=actual.replace(')','')
    actual=actual.replace('(same day as','-')
    actual=actual.replace('"Bitten last weekend','')
    actual=actual.replace('Some time between','')
    actual=actual.replace('Before','')
    
    try:
        actual2=pd.to_datetime(actual)
        return actual2
    except:
        return actual

# %%
sharks.Date=sharks.Date.apply(date)

# %%
sharks.drop(columns = ['Year'], inplace = True)

# %%
sharks.Country=sharks.Country.str.lower().str.capitalize()

# %%
sharks
# Out:
#      Case Number                 Date        Type             Country  \
# 0     2018.06.25  2018-06-25 00:00:00    Provoked                 Usa
# 1     2018.06.18  2018-06-18 00:00:00  Unprovoked                 Usa
# 2     2018.06.09  2018-06-09 00:00:00    Provoked                 Usa
# 3     2018.06.08  2018-06-08 00:00:00  Unprovoked           Australia
# 4     2018.06.04  2018-06-04 00:00:00    Provoked              Mexico
# ...          ...                  ...         ...                 ...
# 6297     ND.0005  1903-01-01 00:00:00  Unprovoked           Australia
# 6298     ND.0004  1903-01-01 00:00:00  Unprovoked           Australia
# 6299     ND.0003            1900-1905  Unprovoked                 Usa
# 6300     ND.0002            1883-1889  Unprovoked              Panama
# 6301     ND.0001            1845-1853  Unprovoked  Ceylon (sri lanka)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks['Country'].isnull().sum()
# Out:
# 50

# %%
col=list(sharks.columns)

# %%
for colu in col:
    sharks[f'{colu}']=sharks[f'{colu}'].fillna('No Data')

# %%
sharks
# Out:
#      Case Number                 Date        Type             Country  \
# 0     2018.06.25  2018-06-25 00:00:00    Provoked                 Usa
# 1     2018.06.18  2018-06-18 00:00:00  Unprovoked                 Usa
# 2     2018.06.09  2018-06-09 00:00:00    Provoked                 Usa
# 3     2018.06.08  2018-06-08 00:00:00  Unprovoked           Australia
# 4     2018.06.04  2018-06-04 00:00:00    Provoked              Mexico
# ...          ...                  ...         ...                 ...
# 6297     ND.0005  1903-01-01 00:00:00  Unprovoked           Australia
# 6298     ND.0004  1903-01-01 00:00:00  Unprovoked           Australia
# 6299     ND.0003            1900-1905  Unprovoked                 Usa
# 6300     ND.0002            1883-1889  Unprovoked              Panama
# 6301     ND.0001            1845-1853  Unprovoked  Ceylon (sri lanka)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks.to_csv('sharks_clean.csv', index=False)
