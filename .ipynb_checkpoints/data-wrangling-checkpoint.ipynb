# %% [markdown]
# # Project: Data Cleaning and Manipulation with Pandas
# ## Sofía Aceves

# %%
import pandas as pd
import numpy as np
import re
import datetime

# %%
data = pd.read_csv('C:/Users/Sofía Aceves Osuna/ironhack/Clases/attacks.csv')
"""""
Initial plan
1. Clean nans taking in account the most important columns as base to make this decision
2. Choose a relevant index (set 'original order' as index)
3. Clean Date column 
3.1 Homologate format (25-jun-18) changing dtype
3.2 Clean values picking out the most relevant info
4. Turn year into integer( or whatever datatype corresponding to year)
5. Get rid of extra columns ('Unnamed: 22', 'Unnamed: 23')
"""""
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Get to see and analyse the global perspective of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
# Review nulls to see if the decision of eliminating nulls can be made based on the quantity of missing values in each row
data.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
# 1. General cleaning: get rid of na
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
# Analysing nulls, noticed that the rows that didn't have data in columns 'Case Number' and 'Date' were empty in the other columns too.
clean_df = data.dropna(axis=0, how='all', thresh= 2, subset = ['Case Number', 'Date'])

# %%
# 2. Get rid of unuseful columns
# Analysing columns, noticed that the columns 'Unnamed: 22', 'Unnamed: 23' have too much nulls
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
final_df = clean_df.drop(columns=['Unnamed: 22', 'Unnamed: 23'])
final_df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
# Analysing the "Case Number.1" and "Case Number.2" columns, they have the same value as the 'Case Number' column, so they can be removed
final_df['Case Number'] == final_df['Case Number.1']
final_df['Case Number'] == final_df['Case Number.2']
final_df = final_df.drop(columns=['Case Number.1', 'Case Number.2'])
final_df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
# 3. Adjust dtype of column that it's going to turn into the index
type_list = {'original order':int}
final_df1 = final_df.astype(type_list)

# 4. Clean the date column as much as possible, considering the different ways data has been input, using regex
final_df2 = [re.findall('\d{1,2}\W+\w+\W+\d{4}|\d{2}\W\w+\W\d{2}|\d{4}|\w{3}-\d+', item) for it in final_df1['Date'] for i in it for item in i] 
final_df1

# %%
# 5. Set a unique, ordered, and relevant column as index
final_df3 = final_df1.set_index('original order')
final_df3
# Out:
#                Case Number         Date    Year        Type  \
# original order
# 6303            2018.06.25  25-Jun-2018  2018.0     Boating
# 6302            2018.06.18  18-Jun-2018  2018.0  Unprovoked
# 6301            2018.06.09  09-Jun-2018  2018.0     Invalid
# 6300            2018.06.08  08-Jun-2018  2018.0  Unprovoked
# 6299            2018.06.04  04-Jun-2018  2018.0    Provoked
# ...                    ...          ...     ...         ...
# 6                  ND.0005  Before 1903     0.0  Unprovoked
# 5                  ND.0004  Before 1903     0.0  Unprovoked
# 4                  ND.0003    1900-1905     0.0  Unprovoked
# 3                  ND.0002    1883-1889     0.0  Unprovoked
# 2                  ND.0001    1845-1853     0.0  Unprovoked
#
#                            Country               Area  \
# original order
# 6303                           USA         California
# 6302                           USA            Georgia
# ...

# %%
# 6. Set 'Date' and 'Year' columns into the corresponding data type: datetime
final_df3.loc[(final_df3['Year'].isnull()),'Year']=0
final_df3['Year'] = pd.to_datetime((final_df3['Year']), errors= 'ignore', format = "%Y")
final_df3['Date'] = pd.to_datetime((final_df3['Date']), errors= 'ignore', format = "%m/%d/%Y")
final_df3
# Out:
#                Case Number         Date  Year        Type             Country  \
# original order
# 6303            2018.06.25  25-Jun-2018  2018     Boating                 USA
# 6302            2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 6301            2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 6300            2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 6299            2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...                    ...          ...   ...         ...                 ...
# 6                  ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5                  ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 4                  ND.0003    1900-1905     0  Unprovoked                 USA
# 3                  ND.0002    1883-1889     0  Unprovoked              PANAMA
# 2                  ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
# ...

# %%
#Crazy idea of using the year=0 to identify the dates that needed some cleaning so I could clean the date and use that info to input info to year
#final_df3.loc[final_df3['Year'] & 'Before' in final_df3['Date']]
