# %%
import pandas as pd 
import requests
import re
import numpy as np

# %%
data=pd.read_csv("C:/Users/Tania/Desktop/shark.csv")

# %%
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
data.shape
# Out:
# (5992, 24)

# %%
null_cols=data.isnull().sum()
null_cols[null_cols>0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Checamos las columnas que tienen mas nulos Unnamed: 22 y Unnamed: 23
print(set(data["Unnamed: 22"]))
print(set(data["Unnamed: 23"]))
#Como en estas columnas solo hay uno y dos valores distintos de nulos correspondientemente, 
#y ni siquiera tienen nombre para saber a que se refieren, lo mejor será eliminarlas
# Out:
# {nan, 'stopped here'}
# {nan, 'change filename', 'Teramo'}

# %%
borrar=["Unnamed: 22","Unnamed: 23"]
data=data.drop(borrar, axis=1)

# %%
data.columns
#verificamos que ya no estan esas columnas en el df
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
#Renombramos las columnas para facilitar su uso
new_col=data.columns.str.lower().str.strip().str.replace(" ", "_")
data.columns=new_col
data.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal_(y/n)', 'time',
#        'species', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number.1', 'case_number.2', 'original_order'],
#       dtype='object')

# %%
#vemos cuantos renglones tienen diferentes valores en las columnas href y href_formula
href_data=data[(data["href"]!=data["href_formula"])]
href_data=href_data[["href","href_formula"]]
href_data.shape
#Son pocos los renglones en los que la columna href y href_formula son distintos por lo que 
#podríamos checar en que se diferencían esos pocos y solo dejar una columna en el data frame original
# Out:
# (54, 2)

# %%
#Para poder manejar mejor los datos, asignamos valor de cero a los nulos y tambien a las celdas que no tienen  asignado un href
href_data[["href","href_formula"]]=href_data[["href","href_formula"]].fillna(0)
href_data["href"][365]=0
href_data["href_formula"][448]=0
href_data
# Out:
#                                                    href  \
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 107   http://sharkattackfile.net/spreadsheets/pdf_di...
# 114   http://sharkattackfile.net/spreadsheets/pdf_di...
# 134   http://sharkattackfile.net/spreadsheets/pdf_di...
# 180   http://sharkattackfile.net/spreadsheets/pdf_di...
# 193                                                   0
# 232   http://sharkattackfile.net/spreadsheets/pdf_di...
# 262   http://sharkattackfile.net/spreadsheets/pdf_di...
# 263   http://sharkattackfile.net/spreadsheets/pdf_di...
# 264   http://sharkattackfile.net/spreadsheets/pdf_di...
# 271   http://sharkattackfile.net/spreadsheets/pdf_di...
# 272   http://sharkattackfile.net/spreadsheets/pdf_di...
# 293   http://sharkattackfile.net/spreadsheets/pdf_di...
# 305   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
#Vamos a checar que links de la columna href dan error para despues intercambiarlos por el link en la columna href_formula

stat_href=[]
for link in href_data["href"]:
    if link!=0:
        html=requests.get(link)
        if html.status_code==404:
            stat_href.append("error")
        else:
            stat_href.append( "bien")
    else:
        stat_href.append("nan")

# %%
#cree otra columna con el estado del link de href para visualizar mejor los datos a investigar
href_data["stat_href"]=stat_href
href_data
# Out:
#                                                    href  \
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 107   http://sharkattackfile.net/spreadsheets/pdf_di...
# 114   http://sharkattackfile.net/spreadsheets/pdf_di...
# 134   http://sharkattackfile.net/spreadsheets/pdf_di...
# 180   http://sharkattackfile.net/spreadsheets/pdf_di...
# 193                                                   0
# 232   http://sharkattackfile.net/spreadsheets/pdf_di...
# 262   http://sharkattackfile.net/spreadsheets/pdf_di...
# 263   http://sharkattackfile.net/spreadsheets/pdf_di...
# 264   http://sharkattackfile.net/spreadsheets/pdf_di...
# 271   http://sharkattackfile.net/spreadsheets/pdf_di...
# 272   http://sharkattackfile.net/spreadsheets/pdf_di...
# 293   http://sharkattackfile.net/spreadsheets/pdf_di...
# 305   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
#Asignamos el link de href_formula a las celdas de la columna href donde stat_href es error o nulo 
href_data.loc[(href_data["stat_href"]=="error")|(href_data["stat_href"]=="nan"),"href"]=href_data["href_formula"]
lista=href_data["href"].index

# %%
#Cambiamos los valores de href necesarios en el data frame original con ayuda de una lista de indices donde 
#queremos hacer los cambios
data.loc[lista,"href"]=href_data["href"]

# %%
# Ahora si podemos eliminar la columna href_formula del data frame original ya que no nos aporta información diferente

data=data.drop("href_formula", axis=1)

# %%
#Analicemos la columna sex
data.sex.value_counts()
# Out:
# M      4835
# F       585
# M         2
# lli       1
# N         1
# .         1
# Name: sex, dtype: int64

# %%
data[data.sex=="lli"]
#Vemos que el nombre es de hombre así que cambiamos su sexo a M
# Out:
#        case_number       date  year        type country        area  \
# 1400  2004.11.11.b  11-Nov-04  2004  Unprovoked     USA  California
#
#                                             location activity        name  \
# 1400  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#       sex  ...                              injury fatal_(y/n)   time  \
# 1400  lli  ...  Lacerations to hand, knee & thigh            N  13h30
#
#                       species            investigator_or_source  \
# 1400  5.5 m [18'] white shark  R. Collier, GSAF
#
#                         pdf  \
# 1400  2004.11.11.b-Kang.pdf
#
#                                                    href case_number.1  \
# 1400  http://sharkattackfile.net/spreadsheets/pdf_di...  2004.11.11.b
#
#      case_number.2 original_order
# 1400  2004.11.11.b           4593
#
# [1 rows x 21 columns]

# %%
data.loc[data.sex=="lli", "sex"]="M"

# %%
data[data.sex=="N"]
#Vemos que no se trata de una persona en específico, sino de varias y no se saben sus sexos
# Out:
#      case_number       date  year     type    country             area  \
# 4708  1934.07.11  11-Jul-34  1934  Boating  AUSTRALIA  New South Wales
#
#       location activity                                         name sex  ...  \
# 4708  Cronulla  Fishing  18' boat, occupants William & Leslie Newton   N  ...
#
#                                                  injury fatal_(y/n) time  \
# 4708  No injury to occupants Sharks continually foll...           N  NaN
#
#                  species                             investigator_or_source  \
# 4708  Blue pointer, 11'   G.P. Whitley, ref: Daily Telegraph, 7/11/1934 ...
#
#                                        pdf  \
# 4708  1934.07.11-Newton-boat-Australia.pdf
#
#                                                    href case_number.1  \
# 4708  http://sharkattackfile.net/spreadsheets/pdf_di...    1934.07.11
#
#      case_number.2 original_order
# 4708    1934.07.11           1285
#
# [1 rows x 21 columns]

# %%
data[data.sex=="."]
#Aquí tambien vemos que no se trata de una persona en específico, sino de varias y no se saben sus sexos
# Out:
#        case_number                  date  year          type  \
# 5201  1908.06.02.R  Reported 02-Jun-1908  1908  Sea Disaster
#
#                country         area location activity name sex  ...  \
# 5201  PAPUA NEW GUINEA  New Britain   Matupi        .  NaN   .  ...
#
#                                                  injury fatal_(y/n) time  \
# 5201  Remains of 3 humans recovered from shark, but ...           Y  NaN
#
#                         species     investigator_or_source  \
# 5201  Allegedly a 33-foot shark  Taranaki Herald, 6/2/1908
#
#                           pdf  \
# 5201  1908.06.02.R-Matupi.pdf
#
#                                                    href case_number.1  \
# 5201  http://sharkattackfile.net/spreadsheets/pdf_di...  1908.06.02.R
#
#      case_number.2 original_order
# 5201  1908.06.02.R            792
#
# [1 rows x 21 columns]

# %%
data.loc[data.sex=="N", "sex"]="unknown"
data.loc[data.sex==".", "sex"]="unknown"

# %%
data.sex=data.sex.str.lower().str.strip()

# %%
data.sex.value_counts()
# Out:
# m          4838
# f           585
# unknown       2
# Name: sex, dtype: int64

# %%
#Veremos si hay renglones duplicados
data.shape
# Out:
# (5992, 21)

# %%
#Trate de borrar renglones duplicados pero no hubo duplicados
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (5992, 21)

# %%
#Checaremos la columna que nos informa si el evento fue fatal o no
data["fatal_(y/n)"].value_counts()
# Out:
# N          4315
# Y          1552
# UNKNOWN      94
#  N            8
# #VALUE!       1
# F             1
# N             1
# n             1
# Name: fatal_(y/n), dtype: int64

# %%
data["fatal_(y/n)"]=data["fatal_(y/n)"].str.lower().str.strip()

# %%
data["fatal_(y/n)"].value_counts()
# Out:
# n          4325
# y          1552
# unknown      94
# f             1
# #value!       1
# Name: fatal_(y/n), dtype: int64

# %%
#Checamos a que se refiere el valor f y vemos que solo se encontraron restos humanos entonces si fue fatal
data[data["fatal_(y/n)"]=="f"]
# Out:
#        case_number                  date  year     type country       area  \
# 4693  1935.01.21.R  Reported 21-Jan-1935  1935  Invalid  ISRAEL  Herzliyah
#
#        location activity name  sex  ...                      injury  \
# 4693  Sidny Ali      NaN  NaN  NaN  ...  human remains washed ahore
#
#      fatal_(y/n) time species investigator_or_source  \
# 4693           f  NaN     NaN         C. Moore, GSAF
#
#                             pdf  \
# 4693  1935.01.21.R-SidnyAli.pdf
#
#                                                    href case_number.1  \
# 4693  http://sharkattackfile.net/spreadsheets/pdf_di...  1935.01.21.R
#
#      case_number.2 original_order
# 4693  1935.01.21.R           1300
#
# [1 rows x 21 columns]

# %%
#Hacemos el cambio
data.loc[data["fatal_(y/n)"]=="f", "fatal_(y/n)"]="y"

# %%
#Vemos que significa el valor #value! y vemos que hablan sobre un forence entonces si fue fatal
data[data["fatal_(y/n)"]=="#value!"]
# Out:
#      case_number         date  year     type       country  \
# 5461  1890.05.14  14-May-1890  1890  Invalid  SOUTH AFRICA
#
#                        area        location activity          name sex  ...  \
# 5461  Eastern Cape Province  Port Elizabeth      NaN  Joseph Lundy   m  ...
#
#                                                  injury fatal_(y/n) time  \
# 5461  Forensic evidence indicated death resulted fro...     #value!  NaN
#
#      species investigator_or_source                   pdf  \
# 5461     NaN        M. Levine, GSAF  1890.05.14-Lundy.pdf
#
#                                                    href case_number.1  \
# 5461  http://sharkattackfile.net/spreadsheets/pdf_di...    1890.05.14
#
#      case_number.2 original_order
# 5461    1890.05.14            532
#
# [1 rows x 21 columns]

# %%
#Hacemos el cambio
data.loc[data["fatal_(y/n)"]=="#value!", "fatal_(y/n)"]="y"

# %%
data["fatal_(y/n)"].value_counts()
# Out:
# n          4325
# y          1554
# unknown      94
# Name: fatal_(y/n), dtype: int64

# %%
#Checaremos si hay alguna columna con poca variabilidad para poder eliminarla 
varianza_baja = []
for column in data._get_numeric_data():
    minimo = data[column].min()
    per90 = data[column].quantile(0.90)
    maximo = data[column].max()
    per10 = data[column].quantile(0.10)
    if minimo == per90 or maximo == per10:
        varianza_baja.append(column)

# %%
varianza_baja
#No hay alguna columna que podamos eliminar por tener baja variación, las únicas opciones
# eran la columna year o la columna original_order porque son las únicas columnas numéricas
# Out:
# []

# %%
#Vemos el caso de las columnas case_number y case_number.1 para ver si podemos quitar alguna de las dos, 
#y vemos que solo hay 13 datos distintos entre ambas columnas
case_data=data[(data["case_number"]!=data["case_number.1"])]
case_data=case_data[["case_number","case_number.1", "case_number.2", "href"]]
case_data.shape
# Out:
# (13, 4)

# %%
#son los renglones donde case_number=case_number.1
case_data
# Out:
#        case_number case_number.1 case_number.2  \
# 4       2016.09.15    2016.09.16    2016.09.15
# 33    2016.07.14.4  2016.07.14.R  2016.07.14.4
# 97    2016.01.24.b  2015.01.24.b  2016.01.24.b
# 116     2015.12.23    2015.11.07    2015.12.23
# 121   2015.10.28.a    2015.10.28  2015.10.28.a
# 169     2015.07-10    2015.07.10    2015.07.10
# 3296    1967.07.05    1967/07.05    1967.07.05
# 3569  1962,08.30.b  1962.08.30.b  1962,08.30.b
# 3654  1961.09.02.R  1961.09,06.R  1961.09.02.R
# 4177    1952.08.05    1952.08.04    1952.08.05
# 4719  1934.01.08.R  1934.02.08.R  1934.02.08.R
# 5043  1900.00.00.R  1919.00.00.R  1900.00.00.R
# 5150  1911.07.31.R  1911.07.31.T  1911.07.31.R
#
#                                                    href
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# 33    http://sharkattackfile.net/spreadsheets/pdf_di...
# 97    http://sharkattackfile.net/spreadsheets/pdf_di...
# 116   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
case_data1=data[(data["case_number.2"]!=data["case_number.1"])]
case_data1=case_data1[["case_number","case_number.1", "case_number.2", "href"]]
case_data1
#Son los renglones dende case_number.1=case_number.2 Son los mismos casos que en la tabla de arriba salvo los renglones 169 y 4719
# Out:
#        case_number case_number.1 case_number.2  \
# 4       2016.09.15    2016.09.16    2016.09.15
# 33    2016.07.14.4  2016.07.14.R  2016.07.14.4
# 97    2016.01.24.b  2015.01.24.b  2016.01.24.b
# 116     2015.12.23    2015.11.07    2015.12.23
# 121   2015.10.28.a    2015.10.28  2015.10.28.a
# 3296    1967.07.05    1967/07.05    1967.07.05
# 3569  1962,08.30.b  1962.08.30.b  1962,08.30.b
# 3654  1961.09.02.R  1961.09,06.R  1961.09.02.R
# 4177    1952.08.05    1952.08.04    1952.08.05
# 5043  1900.00.00.R  1919.00.00.R  1900.00.00.R
# 5150  1911.07.31.R  1911.07.31.T  1911.07.31.R
#
#                                                    href
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# 33    http://sharkattackfile.net/spreadsheets/pdf_di...
# 97    http://sharkattackfile.net/spreadsheets/pdf_di...
# 116   http://sharkattackfile.net/spreadsheets/pdf_di...
# 121   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3296  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
#solucionamos el renglon 169 entrando al link correspondiente y checando la info del número de caso
data.loc[[169],"case_number"]=data["case_number.1"]

# %%
# checamos la fecha del renglon 4719 ya que tiene que ver con el numero de caso, porque no 
#podemos acceder al link, vemos que coincide la fecha con el numero de caso todas las veces asi que el 
#numero de caso debe coincidir con el numero de caso 1
data.date[4719]
# Out:
# 'Reported 08-Feb-1934'

# %%
#Hacemos el cambio
data.loc[[4719],"case_number"]=data["case_number.1"]

# %%
#Otro cambio específico
data.loc[[3654],"case_number"]="1961.09.06.R"

# %%
#Checamos los links de los demas renglones y vemos que en estos renglones, el numero de casos debe ser igual al numero de casos1,
#los demas coinciden con la info en los links
ind=[4,33,116,121,3569,5043]

# %%
#Cambiamos estos datos 
data.loc[ind,"case_number"]=data["case_number.1"]

# %%
#ahora si podemos borrar la columna case_number.1 y la columna case_number. 2 sin que perdamos información 
data=data.drop(["case_number.1","case_number.2"], axis=1)

# %%
#Para la columna de fechas: Hay varias fechas con la palabra Reported, así que limpiaremos 
data.date=data.date.str.strip().str.replace("Reported","")

# %%
#Empezaremos a analizar los datos de la columna date primero veremos cuales renglones tienen un formato de fecha dd-mes-aa
fechas=[]
for fecha in data.date:
    fechas.append(bool(re.fullmatch("\d{2}-[A-Z][a-z]{2}-\d{2}",fecha)))

# %%
fec=np.array(fechas)
fec
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
fe=data[fec][["date", "year", "time"]]
lis=fe.index
fe
# Out:
#            date  year       time
# 0     18-Sep-16  2016      13h00
# 1     18-Sep-16  2016      11h00
# 2     18-Sep-16  2016      10h43
# 3     17-Sep-16  2016        NaN
# 4     16-Sep-16  2016        NaN
# ...         ...   ...        ...
# 5318  21-Aug-00  1900  Afternoon
# 5319  31-Jul-00  1900        NaN
# 5320  14-Jul-00  1900        NaN
# 5595  10-Jun-78  1878        NaN
# 5747  28-Jul-52  1852        NaN
#
# [4314 rows x 3 columns]

# %%
#Vemos que son muchos renglones, pero si queremos quitar la columna de year, es necesario que el año en la fecha este completo
#Así que modificamos el formato a dd-mes-aaaa
for i in lis:
    data.loc[i,"date"]=str(data.loc[i,"date"][0:7])+str(data["year"][i])

# %%
#Hacemos otro cambio 
data.date=data.date.str.strip().str.replace("--","-")

# %%
#si vemos cuantos renglones tienen ahora el formato dd-mes-aaaa vemos que son una gran cantidad 5081
fechas1=[]
for fecha in data.date:
    fechas1.append(bool(re.fullmatch("\d{2}-[A-Z][a-z]{2}-\d{4}",fecha)))
fen=np.array(fechas1)    
fe1=data[fen][["date", "year", "time"]]
fe1
# Out:
#              date  year   time
# 0     18-Sep-2016  2016  13h00
# 1     18-Sep-2016  2016  11h00
# 2     18-Sep-2016  2016  10h43
# 3     17-Sep-2016  2016    NaN
# 4     16-Sep-2016  2016    NaN
# ...           ...   ...    ...
# 5836  26-Sep-1785  1785    NaN
# 5840  12-Jul-1771  1771    NaN
# 5847  17-Dec-1742  1742    NaN
# 5848  06-Apr-1738  1738    NaN
# 5851  26-Mar-1703  1703  Night
#
# [5081 rows x 3 columns]

# %%
#Vemos ahora que tipo de formato de fecha tienen los datos faltantes y cuantos son     
fel=data[~fen][["date", "year", "time"]]
fel
#Solo hay 913 renglones donde la fecha no tiene el formato dd-mes-aaaa
# Out:
#              date  year time
# 151        Sep-15  2015  NaN
# 282        Sep-14  2014  NaN
# 303        Aug-14  2014  NaN
# 366          2014  2014  NaN
# 496        Dec-12  2012  NaN
# ...           ...   ...  ...
# 5987  Before 1903     0  NaN
# 5988  Before 1903     0  NaN
# 5989    1900-1905     0  NaN
# 5990    1883-1889     0  NaN
# 5991    1845-1853     0  NaN
#
# [911 rows x 3 columns]

# %%
#Veamos cuantos renglones tienen el segundo formato que puede tener la fecha: mes-aa
fechas2=[]
for fecha in data.date:
    fechas2.append(bool(re.fullmatch("[A-Z][a-z]{2}-\d{2}",fecha)))
fen2=np.array(fechas2)    
fe2=data[fen2][["date", "year", "time"]]
fe2
# Out:
#         date  year time
# 151   Sep-15  2015  NaN
# 282   Sep-14  2014  NaN
# 303   Aug-14  2014  NaN
# 496   Dec-12  2012  NaN
# 579   Apr-13  2012  NaN
# ...      ...   ...  ...
# 5267  Sep-04  1904  NaN
# 5268  Aug-04  1904  NaN
# 5280  Jul-03  1903  NaN
# 5297  Jun-02  1902  NaN
# 5298  Apr-02  1902  NaN
#
# [284 rows x 3 columns]

# %%
#Lo cambiaré a un formato en el que el año aparezca completo 
lis1=fe2.index
for i in lis1:
    data.loc[i,"date"]=str(data.loc[i,"date"][0:4])+str(data["year"][i])

# %%
#Veamos que otros formatos aparecen en la columna y cuantos son 
fecha3=[]
for fecha in data.date:
    fecha3.append(bool(re.fullmatch("[A-Z][a-z]{2}-\d{4}|\d{2}-[A-Z][a-z]{2}-\d{4}",fecha)))
fen3=np.array(fecha3)    
fe3=data[~fen3][["date", "year", "time"]]
fe3
# Out:
#                date  year   time
# 366            2014  2014    NaN
# 732     12-Jan 2011  2011    NaN
# 813     190Feb-2010  2010  Night
# 1016  Late Jul-2008  2008    NaN
# 1074      Fall 2008  2008    NaN
# ...             ...   ...    ...
# 5987    Before 1903     0    NaN
# 5988    Before 1903     0    NaN
# 5989      1900-1905     0    NaN
# 5990      1883-1889     0    NaN
# 5991      1845-1853     0    NaN
#
# [601 rows x 3 columns]

# %%
#Vamos a dejar el formato de fecha en el que solo aparezca el año y ver que otros formatos hay y cuantos son
fecha4=[]
for fecha in data.date:
    fecha4.append(bool(re.fullmatch("[A-Z][a-z]{2}-\d{4}|\d{2}-[A-Z][a-z]{2}-\d{4}|\d{4}",fecha)))
fen4=np.array(fecha4)    
fe4=data[~fen4][["date", "year", "time"]]
fe4
# Out:
#                date  year   time
# 732     12-Jan 2011  2011    NaN
# 813     190Feb-2010  2010  Night
# 1016  Late Jul-2008  2008    NaN
# 1074      Fall 2008  2008    NaN
# 1075    Summer-2008  2008    NaN
# ...             ...   ...    ...
# 5987    Before 1903     0    NaN
# 5988    Before 1903     0    NaN
# 5989      1900-1905     0    NaN
# 5990      1883-1889     0    NaN
# 5991      1845-1853     0    NaN
#
# [314 rows x 3 columns]

# %%
#Hacemos algunos cambios puntuales que pudimos observar para que queden dentro de alguno de los formatos anteriores
data.loc[732,"date"]="12-Jan-2011"
data.loc[813,"date"]="19-Feb-2010"
data.loc[1133,"date"]="19-Jul-2007"
data.loc[1134,"date"]="19-Jul-2007"

# %%
#Vemos que hay otro formato de fecha Before aaaa, si lo omitimos veremos que otros formatos hay y cuantos son 
fecha5=[]
for fecha in data.date:
    fecha5.append(bool(re.fullmatch("[A-Z][a-z]{2}-\d{4}|\d{2}-[A-Z][a-z]{2}-\d{4}|\d{4}|Before\W\d{4}",fecha)))
fen5=np.array(fecha5)    
fe5=data[~fen5][["date", "year", "time"]]
fe5
# Out:
#                              date  year   time
# 1016                Late Jul-2008  2008    NaN
# 1074                    Fall 2008  2008    NaN
# 1075                  Summer-2008  2008    NaN
# 1224               Early Aug-2006  2006    NaN
# 1238                 09-Jul-2006.  2006  13h00
# ...                           ...   ...    ...
# 5980  Before          19-Jul-1913     0    NaN
# 5982                   Circa 1862     0    NaN
# 5989                    1900-1905     0    NaN
# 5990                    1883-1889     0    NaN
# 5991                    1845-1853     0    NaN
#
# [255 rows x 3 columns]

# %%
#Hacemos algunos cambios para limpiar mas las fechas, quite palabras como la estacion del año o si fue temprano o tarde durante el año
#ya que no creo que sea muy relevante y para que mas datos caigan en los formatos anteriores
data.date=data.date.str.replace("Fall","").str.strip()
data.date=data.date.str.replace("Late","").str.replace("Early","").str.replace("Summer","").str.replace("Winter","").str.replace("of","").str.replace("Reportd","").str.replace("Mid-","").str.replace("mid-","").str.replace("?","").str.replace("          ", "").str.strip()
# Out:
# <ipython-input-66-d581a97f5b63>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data.date=data.date.str.replace("Late","").str.replace("Early","").str.replace("Summer","").str.replace("Winter","").str.replace("of","").str.replace("Reportd","").str.replace("Mid-","").str.replace("mid-","").str.replace("?","").str.replace("          ", "").str.strip()

# %%
#Hacemos algunos otros cambios puntuales que pudimos ver al observar los datos con .unique()
data.loc[1075,"date"]="2008"
data.loc[1238,"date"]="09-Jul-2006"
data.loc[1301,"date"]="24-Nov-2005"
data.loc[1743,"date"]="02-Apr-2001"
data.loc[2021,"date"]="02-Jul-1997"
data.loc[2272,"date"]="May-1993"

# %%
#Observamos que hay otros formatos que se repiten como: No date, aaaas los omitimos y vemos que formatos quedan y cuantos
fecha5=[]
for fecha in data.date:
    fecha5.append(bool(re.fullmatch("[A-Z][a-z]{2}-\d{4}|\d{2}-[A-Z][a-z]{2}-\d{4}|\d{4}|Before\W\d{4}|No\Wdate|\d{4}s",fecha)))
fen5=np.array(fecha5)    
fe5=data[~fen5][["date", "year", "time"]]
fe5
# Out:
#                                                  date  year   time
# 1431  19-Jul-2004  to have happened  "on the weekend"  2004    NaN
# 2234                 Last incident  1994 in Hong Kong  1994    NaN
# 2289                           Between May & Nov-1993  1993    NaN
# 2628                     Mid Jul-1985 or mid Jul-1986  1985  16h00
# 2731                                         Ca. 1983  1983    NaN
# ...                                               ...   ...    ...
# 5980                                Before19-Jul-1913     0    NaN
# 5982                                       Circa 1862     0    NaN
# 5989                                        1900-1905     0    NaN
# 5990                                        1883-1889     0    NaN
# 5991                                        1845-1853     0    NaN
#
# [173 rows x 3 columns]

# %%
#Limpie los datos lo mas que pude para que la mayoria tenga los siguientes formatos: dd-mes-aaa, mes-aaaa, aaaa, 
#Before aaaa,No date, aaaas
data.loc[2823,"date"]="30-Dic-1980"
data.loc[2900,"date"]="Apr-1978"
data.loc[2990,"date"]="26-Jul-1975"
data.loc[3338,"date"]="Aug-1966"
data.loc[3800,"date"]="1960"
data.loc[3852,"date"]="1959"
data.loc[4102,"date"]="1954"
data.loc[4240,"date"]="19-Jul-1950"
data.loc[4610,"date"]="26-Sep-1937"
data.loc[4651,"date"]="08-Apr-1936"
data.loc[4896,"date"]="09-May-1927"
data.loc[5299,"date"]="22-Feb-1902"
data.loc[5244,"date"]="10-Apr-1906"
data.loc[5245,"date"]="02-Apr-1906"
data.loc[5304,"date"]="Oct-1901"
data.loc[5374,"date"]="23-Dec-1896"
data.loc[5392,"date"]="02-Aug-1895"
data.loc[5456,"date"]="09-Aug-1890"
data.loc[5458,"date"]="26-Jun-1890"
data.loc[5495,"date"]="Oct-1887"
data.loc[4417,"date"]="22-Jul-1944"
data.loc[5575,"date"]="1880"
data.loc[5583,"date"]="03-Jul-1879"
data.loc[5596,"date"]="30-Mar-1878"
data.loc[5634,"date"]="09-Jan-1874"
data.loc[5670,"date"]="1868"
data.loc[5636,"date"]="28-Sep-1853"
data.loc[5776,"date"]="16-Jul-1844"
data.loc[5794,"date"]="26-Jul-1836"
data.loc[5795,"date"]="1836"
data.loc[5767,"date"]="1847"
data.loc[5801,"date"]="22-Jan-1831"
data.loc[5817,"date"]="1825"
data.loc[5825,"date"]="03-Sep-1816"
data.loc[5825,"date"]="May-1812"
data.loc[5850,"date"]="June-1721"
data.loc[5855,"date"]="1642"
data.loc[5869,"date"]="336 B.C."

# %%
#Volvemos a correr y ya solo 119 datos tienen un formato distinto, mas explicativo
fecha5=[]
for fecha in data.date:
    fecha5.append(bool(re.fullmatch("[A-Z][a-z]{2}-\d{4}|\d{2}-[A-Z][a-z]{2}-\d{4}|\d{4}|Before\W\d{4}|No\Wdate|\d{4}s|Circa\W\d{4}|\d{4}-\d{4}",fecha)))
fen5=np.array(fecha5)    
fe5=data[~fen5][["date", "year", "time"]]
fe5
# Out:
#                                                    date  year   time
# 1431    19-Jul-2004  to have happened  "on the weekend"  2004    NaN
# 2234                   Last incident  1994 in Hong Kong  1994    NaN
# 2289                             Between May & Nov-1993  1993    NaN
# 2628                       Mid Jul-1985 or mid Jul-1986  1985  16h00
# 2731                                           Ca. 1983  1983    NaN
# ...                                                 ...   ...    ...
# 5968                                Between 1918 & 1939     0    NaN
# 5972                                         1920 -1923     0    NaN
# 5978                                  Before17-Jul-1916     0    NaN
# 5979  No date (3 days after preceding incident) & pr...     0    NaN
# 5980                                  Before19-Jul-1913     0    NaN
#
# [119 rows x 3 columns]

# %%
fe5.date.unique()
#Aquí estan los demas formatos, como son muy pocos a comparación del total, ya no los simplificare mas
# Out:
# array(['19-Jul-2004  to have happened  "on the weekend"',
#        'Last incident  1994 in Hong Kong', 'Between May & Nov-1993',
#        'Mid Jul-1985 or mid Jul-1986', 'Ca. 1983', 'Ca. 1970',
#        '13 or 30-May-1967', 'May-Jun-1965', 'Ca. 1965', 'Jan-Jun-1962',
#        'Ca. 1962', 'Ca. 1960', 'Between 10 and 12-Sep-1959',
#        'Jul- to Sep-1959', 'Ca. 1955', '1954 (same day as  1954.00.00.f)',
#        'Between 01-Aug-1951 & 08-Aug-1951', '1950 - 1951', 'Ca. 1950',
#        'Mar-1949 or Apr-1949', '13-Mar-1948 "Bitten last weekend',
#        'Between 18 & 22-Dec 1944', 'Some time between Apr & Nov-1944',
#        '02-Mar-1943 to 07-Mar-1943', '11-Sep-1942 to 16-Sep-1942',
#        'Ca. 1940', 'Woirld War II', 'Ca. 1939', 'Ca. 1929',
#        'Some time between 08-Jan-1928 & 21-Jan-1928',
#        '07-Mar-1925 or 27-Mar-1925', 'to have taken place in 1919',
#        'Ca. 1915', 'Ca. 1911', '14-Nov-1909 to 19-Nov-1909', 'Ca. 1903',
# ...

# %%
#Dejare la columna de año porque puede ayudar a hacer ciertos análisis, pero la que si borraré será la de original_order
#Ya que era el indice que tenían los datos antes de ser ordenados por año y no proporciona información del tema
data=data.drop(["original_order"], axis=1)

# %%
#Chequemos las otras columnas
data.country=data.country.str.strip().str.replace("?","").str.upper()
#Con esto country queda bien
# Out:
# <ipython-input-73-4857832e8998>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data.country=data.country.str.strip().str.replace("?","").str.upper()

# %%
#No hay mucho que cambiar a las columnas area, location, activity y type
data.area=data.area.str.replace("�","").str.strip()
data.location=data.location.str.replace("�","").str.strip()
data.activity=data.activity.str.strip().str.lower()
data.type=data.type.str.strip().str.lower()

# %%
#Para la columna de time, casí todos los datos tienen el mismo formato solo haremos los siguientes cambios 
data.time=data.time.str.replace("�","").str.replace(" / ","-").str.replace("?","").str.replace(">","").str.replace(" -- ","-").str.replace("--","unknown").str.replace("j","h").str.replace(".","").str.replace("  ","unknown").str.replace("X","unknown")
data.time.unique()
# Out:
# <ipython-input-75-74527516c044>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data.time=data.time.str.replace("�","").str.replace(" / ","-").str.replace("?","").str.replace(">","").str.replace(" -- ","-").str.replace("--","unknown").str.replace("j","h").str.replace(".","").str.replace("  ","unknown").str.replace("X","unknown")
# array(['13h00', '11h00', '10h43', nan, '15h15', '14h30', '15h40',
#        'Late afternoon', '15h00', '14h00', '17h00', '16h00', '11h30',
#        '12h00', '19h05', 'After noon', '1300', '10h00', '14h30-15h30',
#        '22h00', '16h20', '14h34', '15h25', '14h55', '06h00', '17h30',
#        '08h30', 'Morning', 'Afternoon', '15h45', '18h00', '17h46',
#        'Morning ', '13h20', '15h49', '07h00', '08h00', '10h45', '19h00',
#        '13h30', 'Midnight', '12h30', '09h30-10h00', '10h30', '18h15',
# ...

# %%
#En las columnas donde hay nulos, las cambiaremos por unknown
data[["country","area","location","activity","name","sex","age","injury","fatal_(y/n)","time","species","investigator_or_source"]]=data[["country","area","location","activity","name","sex","age","injury","fatal_(y/n)","time","species","investigator_or_source"]].fillna("unknown")

# %%
#Checamos la columna de especies 
data.species=data.species.str.lower().str.strip()
data.species.value_counts()
# Out:
# unknown                                            2935
# white shark                                         163
# shark involvement not confirmed                      81
# tiger shark                                          69
# bull shark                                           55
#                                                    ...
# white shark, 4 to 5 m                                 1
# a "small shark"                                       1
# caribbean reef shark, 1.2 m to 1.5 m [4' to 5']       1
# "a very large shark"                                  1
# blacktip reef shark, 1.5 m [5']                       1
# Name: species, Length: 1442, dtype: int64

# %%
#Hacemos un pequeño cambio para referirnos a lo mismo
data.species=data.species.str.replace("shark involvement not confirmed", "unknown")

# %%
data.species.value_counts()
# Out:
# unknown                                            3016
# white shark                                         163
# tiger shark                                          69
# bull shark                                           55
# 6' shark                                             40
#                                                    ...
# caribbean reef shark, 1.2 m to 1.5 m [4' to 5']       1
# "a very large shark"                                  1
# tiger shark, 4.8 m                                    1
# possibly juvenile tiger shark                         1
# blacktip reef shark, 1.5 m [5']                       1
# Name: species, Length: 1441, dtype: int64

# %%
#Podríamos cambiar el nombre de la columna species por shark_information ya que hay renglones que tienen una descripcion mas alla de la especie del tiburon
#Lo mismo podríamos cambiar el nombre de la columna name a victims ya que no siempre se refiere a nombres los elementos de esa columna
data.rename(columns={"name":"victims","species":"shark_information"}, inplace=True)

# %%
#Por último vemos los tipos de datos de las columnas y si es necesario cambiar alguno 
data.dtypes
# Out:
# case_number               object
# date                      object
# year                       int32
# type                      object
# country                   object
# area                      object
# location                  object
# activity                  object
# victims                   object
# sex                       object
# age                       object
# injury                    object
# fatal_(y/n)               object
# time                      object
# shark_information         object
# investigator_or_source    object
# pdf                       object
# href                      object
# dtype: object

# %%
#Cambiare la columna year a int
data.year=data.year.astype("int")

# %%
data.dtypes
# Out:
# case_number               object
# date                      object
# year                       int32
# type                      object
# country                   object
# area                      object
# location                  object
# activity                  object
# victims                   object
# sex                       object
# age                       object
# injury                    object
# fatal_(y/n)               object
# time                      object
# shark_information         object
# investigator_or_source    object
# pdf                       object
# href                      object
# dtype: object

# %%
tab=data.to_csv("output/clean_sharks.csv")
