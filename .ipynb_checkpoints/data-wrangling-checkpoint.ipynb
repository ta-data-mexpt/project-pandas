# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("/Users/santiago/ih-bootcamp/proyectos/project-pandas/GSAF5.csv")

# %% [markdown]
# # 1. Explorando la data

# %%
df.shape
# Out:
# (5992, 24)

# %%
df.head(5)
#df.tail(5)
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
# porcentaje de valores nulos por columna
df.columns=df.columns.str.replace(" ", "_")
df.columns=df.columns.str.lower()

# %%
nulls=list(zip(df.columns, [sum(df[x].isnull())/len(df[x])*100 for x in df]))

# %%
pd.DataFrame(nulls)
# Out:
#                          0          1
# 0              case_number   0.000000
# 1                     date   0.000000
# 2                     year   0.000000
# 3                     type   0.000000
# 4                  country   0.717623
# 5                     area   6.708945
# 6                 location   8.277704
# 7                 activity   8.795060
# 8                     name   3.337784
# 9                     sex_   9.462617
# 10                     age  44.742991
# 11                  injury   0.450601
# 12             fatal_(y/n)   0.317089
# 13                    time  53.621495
# 14                species_  48.965287
# 15  investigator_or_source   0.250334
# 16                     pdf   0.000000
# 17            href_formula   0.016689
# 18                    href   0.050067
# 19           case_number.1   0.000000
# 20           case_number.2   0.000000
# 21          original_order   0.000000
# 22             unnamed:_22  99.983311
# 23             unnamed:_23  99.966622

# %% [markdown]
# # Puntos a trabajar
#     - Cambiar tipos de datos en variables de fecha a fecha
#     - Tirar variables que no sean útiles y/o con muchos valores nulos
#     - Unificar valores en variables como sex_, fatal_(y/n)
#     - Limpiar valores de variable country para que sean sólo nombres de países, cambiar valores de regiones por NAs
#     - Completar variables con muchos nulos con información de otra fuente.

# %% [markdown]
# ## trabajando con los valores nulos

# %% [markdown]
# ### Tirando unnamed:_23 y unnamed:_22

# %%
print(df["unnamed:_23"].unique(), df["unnamed:_22"].unique())
# Out:
# [nan 'Teramo' 'change filename'] [nan 'stopped here']

# %%
df[df["unnamed:_23"].isnull()!=True]
# Out:
#      case_number         date  year      type    country             area  \
# 4182  1952.07.13    13-Jul-52  1952  Provoked        USA       California
# 5585  1879.03.10  10-Mar-1879  1879   Invalid  AUSTRALIA  New South Wales
#
#                          location  \
# 4182  San Diego, San Diego County
# 5585                 Near Sydney
#
#                                            activity  \
# 4182                                        Fishing
# 5585  The steamship Bonnie Dundee lost in collision
#
#                                                    name sex_  ... species_  \
# 4182  Gerald Howard, on board sportsfishing boat Ter...    M  ...      NaN
# 5585                     Cabin boy of the Bonnie Dundee    M  ...      NaN
#
#       investigator_or_source                           pdf  \
# 4182  L.A. Times, 7/14/1952          1952.07.13-Howard.pdf
# 5585         Star, 3/22/1879  1879.03.10-Bonnie-Dundee.pdf
#
#                                            href_formula  \
# ...

# %%
df[df["unnamed:_22"].isnull()!=True]
# Out:
#      case_number       date  year        type country        area  \
# 1247  2006.06.18  18-Jun-06  2006  Unprovoked  BRAZIL  Pernambuco
#
#                             location       activity                     name  \
# 1247  Punta Del Chifre Beach, Olinda  Body boarding  Humberto Pessoa Batista
#
#      sex_  ... species_ investigator_or_source                     pdf  \
# 1247    M  ...      NaN     globalsurfnews.com  2006.06.18-Batista.pdf
#
#                                            href_formula  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.06.18
#
#      case_number.2 original_order   unnamed:_22 unnamed:_23
# 1247    2006.06.18           4746  stopped here         NaN
#
# [1 rows x 24 columns]

# %%
#al parecer no tienen información relevante las columnas "unnamed:_22" y "unnamed:_23"
df.drop(columns=["unnamed:_22", "unnamed:_23","case_number.1", "case_number.2", "href_formula"], inplace=True)

# %% [markdown]
# ## Trabajo por variables
# ### investigator_or_source

# %%
df.investigator_or_source.nunique()
# Out:
# 4752

# %%
set(df.investigator_or_source.unique())
# Out:
# {nan,
#  'L. Kumpe, R. Mcauley',
#  'Ocala Star Banner, 8/30/1972',
#  'Palm Beach Post, 11/16/2015',
#  'P. Lynch, N. Doveton, G. Wolfe, M.Levine, GSAF ',
#  'Sydney Morning Herald, 7/7/1936; V.M. Coppleson (1958), p.244',
#  'Nelson Examiner & New Zealand Chronicle, 4/24/1869',
#  'Canberra Times, 9/8/1962',
#  'Canberra Times, 6/26/1972',
#  'D.G. McComb',
#  'C. Creswell, GSAF; Washington Post, 10/7/1883, p.2',
#  'Long Beach Independent, 1/281964 ',
#  'Clicanoo, 7/15/2013',
#  'The Queenslander, 12/17/ 1921',
#  'Stuff.co.nz, 1/18/2013',
#  'TC Palm, 2/3/2010',
#  'WFTV,  5/27/2015',
#  'V.M. Coppleson (1962), p.206',
#  'Reno Evening Gazette, 7/11/1879',
#  'B.A. Wright',
#  'Gulfport Herald, 7/12/1963; SAF Case #1218',
#  'G. Cliff & B. Davis, NSB',
#  'A. Cobb & E. Ritter, GSAF',
#  'A. Hartman, M. Levine, GSAF; Cape Argus, 4/26/1974',
#  'BBC, 9/9/2014',
#  'Big Island Now, 12/11/2013',
#  'Sydney Morning Herald, 4/4/1961 ; Launceston Examiner; H.D. Baldridge, pp.133-134',
# ...

# %% [markdown]
# ### Country

# %%
df.country=df.country.str.lower()
df.country.unique()
# Out:
# array(['usa', 'australia', 'new caledonia', 'reunion', 'bahamas', 'spain',
#        'china', 'japan', 'columbia', 'south africa', 'egypt',
#        'new zealand', 'indonesia', 'french polynesia', 'cape verde',
#        'fiji', 'brazil', 'dominican republic', 'cayman islands',
#        'united arab emirates', 'aruba', 'mozambique', 'thailand',
#        'puerto rico', 'italy', 'mexico', 'atlantic ocean', 'greece',
#        'mauritius', nan, 'st. martin', 'france', 'ecuador',
#        'papua new guinea', 'trinidad & tobago', 'kiribati', 'israel',
#        'diego garcia', 'taiwan', 'jamaica', 'palestinian territories',
#        'guam', 'seychelles', 'belize', 'philippines', 'nigeria', 'tonga',
#        'scotland', 'canada', 'croatia', 'saudi arabia', 'chile',
#        'antigua', 'kenya', 'russia', 'turks & caicos', 'costa rica',
#        'united kingdom', 'malaysia', 'united arab emirates (uae)',
#        'samoa', 'azores', 'solomon islands', 'south korea', 'malta',
# ...

# %%
df.country=[re.sub(r"(/ \w* \w*)|(/ \w*)|\?| \(\w* \w*\)", "", str(x)) for x in df.country]
df.country=[re.sub(r".*ocean.*", "", str(x)) for x in df.country]

# Casos específicos
df.country=df.country.replace("between portugal & india", "").replace("asia", "").replace("united arab emirates (uae)", "united arab emirates")
df.country=df.country.replace("gulf of aden", "yemen").replace("tasman sea", "australia")
df.country=df.country.replace("coast of africa", "").replace("mediterranean sea", "").replace("red sea", "egypt")

# %%
#casos que hay que revisar mas: "diego garcia"

# %% [markdown]
# ## Type

# %%
# Unificando boating y boat para reducir una categoría
df.type.unique()
df.type=np.where(df.type=='Boating', 'Boat',df.type)

# %% [markdown]
# ## Sex

# %%
df.sex_.unique()
# Out:
# array(['M', nan, 'F', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
# Revisando y cambiando casos atípicos lli se cambia por M por el 
# nombre (se asume que se Brian se identifica como hombre).
df.sex_=df.sex_.replace('M ', 'M').replace("lli", "M").replace('.', 'nan').replace('N', 'nan')
df.sex_.value_counts()
# Out:
# M      4838
# F       585
# nan       2
# Name: sex_, dtype: int64

# %% [markdown]
# ## Activity

# %%
# Oh no, son muchas actividades diferentes. A continuación se intenta reducirlas lo más posible
df.activity.nunique()
# Out:
# 1492

# %%
set(df.activity.unique())
# Out:
# {nan,
#  'Surfing on "chest board" (boogie board?)',
#  'Collecting shells',
#  'Suicide',
#  'Bathing in knee-deep water',
#  'Fishing for sharks',
#  "Sinking of the 40' Esperanza off St. Maartin with 36 refugees on board",
#  'Spearfishing & had just speared a ulua',
#  'Spearfishing & holding catch',
#  'Swimming / surfing',
#  'Exercising his dog in the shallows',
#  'Swimming, attempting to rescue a girl  believed to be drowning',
#  'Floating on his back in an inner tube',
#  'Skin diving ',
#  'Collecting beche-de-mer',
#  "Overcome by CO fumes, fell overboard from 36' fishing cruiser & prop slashed arm",
#  'Fishing, standing in water next to purse net',
#  'Ran into the water',
#  'Wading after stray fish from seine netter�s catch',
#  'B-24 aircraft crashed  into the sea',
#  'Floating with life preserver after his boat foundered',
#  'Wooden fishing boat',
#  'Body boarding',
#  'Thrown into water from fishing dinghy',
#  'Free diving & spearfishing ',
# ...

# %%
df.activity=df.activity.str.lower()
df.activity=[re.sub(r".*fishing.*|.*swimming.*|.*diving.*|.*surf.*|.*bathing.*|.*fell overvoard.*|.*filming.*|.*floating.*", "", str(x)) for x in df.activity]
df.activity=[re.sub(r".*wreck.*|.*sinking.*|.*boat.*|.*sea disaster.*|.*capsized.*|.*sank.*|.*collided.*|.*sunk.*", "boat wreck", str(x)) for x in df.activity]
df.activity=[re.sub(r".*dived.*", "diving", str(x)) for x in df.activity]
df.activity=[re.sub(r".*fell.*|.*jump.*", "fell/jumped into water", str(x)) for x in df.activity]
df.activity=[re.sub(r".*padling.*|.*rowing.*|.*sailing.*|.*canoeing.*|.*paddling.*|.*paddle.|.*yacht.*", "cruising", str(x)) for x in df.activity]
df.activity=[re.sub(r".*snorkeling.*", "swimming", str(x)) for x in df.activity]
df.activity=[re.sub(r".*adrift.*", "being adrift", str(x)) for x in df.activity]
df.activity=[re.sub(r".*air disaster.*|.*aircaft exploded.*|.*aircraft crashed.*|.*b-24.*|.*boeing.*", "air disaster", str(x)) for x in df.activity]
df.activity=[re.sub(r".*hunting.*|.*netting.*|.*killing.*|.*collecting.*", "fishing", str(x)) for x in df.activity]
df.activity=[re.sub(r".*standing.*|.*wading.*|.*walking.*", "standing/wading in water", str(x)) for x in df.activity]

# %%
# Se redujo a cerca de un cuarto de las actividades originales y se podría continuar reduciendo
df.activity.nunique()
# Out:
# 371

# %% [markdown]
# ## Year

# %%
df.date.nunique()
# Out:
# 5128

# %%
set(df.date.unique())
# Out:
# {'21-Sep-03',
#  '16-Feb-46',
#  '23-Apr-89',
#  'Reported 21-Apr-1892',
#  'May-68',
#  '04-Sep-83',
#  '27-Jul-80',
#  'Reported      23-Aug-1998',
#  '03-May-59',
#  'Reported 18-Sep-2006',
#  '22-Jul-11',
#  '15-Nov-99',
#  'Aug-92',
#  '27-Feb-63',
#  '23-Dec-34',
#  '04-Jul-09',
#  '07-May-00',
#  '17-Aug-92',
#  '04-Aug-61',
#  '20-Jun-05',
#  'Reported 11-Jan-1921',
#  '30-Mar-71',
#  'Reported    27-Mar-2005',
#  '02-Jan-03',
#  'Reported 24-Oct-1878',
#  'Before 1936',
#  'Sep-66',
#  '1993',
#  '28-Jul-63',
#  '30-Sep-84',
#  '13-Feb-82',
#  ' 05-Nov-1997',
#  '27-Feb-60',
#  '1957',
#  'Reported 26-Feb-1804',
#  '23-Dec-92',
#  '23-Jan-04',
#  '25-Jan-48',
#  '15-Sep-16',
#  '22-Jun-1898',
#  '05-Feb-70',
#  '12-Aug-59',
#  'Jan-91',
#  '15-Jul-02',
#  '15-Apr-14',
#  '19-Feb-51',
#  'Reported 25-Jul-1905',
#  'Reported 15-Nov-1921',
#  '1642',
#  '06-Feb-67',
#  '08-Jul-26',
#  '24-May-50',
#  '16-Nov-06',
#  '08-Oct-15',
#  'Jul-00',
#  '28-Apr-10',
#  '14-Jul-96',
# ...

# %%
df.date=df.date.str.lower()
df.date=df.date.str.replace("a few years before 1938", "1938")
df.date=[re.sub(r"no date, before |between|between   |reported |no date, before |before |circa |beforer |early |         |   |\?|reported ", "", str(x)) for x in df.date]
df.date=[re.sub(r"ca. |late| aug-1951 &  |during the war|summer of |mar-1943 to |letter dated| reported| 18 & |sep-1942 to |^ *", "", str(x)) for x in df.date]
df.date=[re.sub(r'summer |decp|1990 or |nov- or|may & |mar-1925 or |jul- to |mid |nov-1909 to |anniversary day" jan-1850 or ', "", str(x)) for x in df.date]
df.date=[re.sub(r' \(same day as  1954.00.00.f\)|reportd |1950 - |1920 -', "", str(x)) for x in df.date]
df.date=[re.sub(r"no date.*|.*b.b..*", "nan", str(x)) for x in df.date]

# %%
#para simplificar tomaré sólo mes y año de fechas
df.date=[re.sub(r"\d\d-", "", str(x)) for x in df.date]

#para estar seguro del año se usa la columna year para pegáreselo a las fechas en los caso en que aplique
df['date_formato'] = [re.search(r"\w{3}-\d{2}$", str(x))!=None for x in df.date]
nueva_date=[]
for i in range(0, len(df.date)):
    if df['date_formato'][i]==True:
        nueva_date.append(re.sub(r"\d\d$","", df['date'][i])+str(df['year'][i]))
    else:
        nueva_date.append(df['date'][i])
df['date']=nueva_date

# %%
df.drop(columns=['date_formato', 'original_order'], inplace=True)

# %%
df[df.date=="jun-1886"]
# Out:
#      case_number      date  year        type    country        area  \
# 5507  1886.06.17  jun-1886  1886  Unprovoked  australia  Queensland
# 5508  1886.06.02  jun-1886  1886     Invalid        usa      Hawaii
#
#                       location activity     name sex_  age  \
# 5507          Off Bribie Heads            Lacoon    M   18
# 5508  Hamakua Homakua, Hawai'i           2 women    F  NaN
#
#                                                  injury fatal_(y/n) time  \
# 5507                                              FATAL           Y  NaN
# 5508  The body of one woman had been bitten by a sha...           Y  NaN
#
#      species_                             investigator_or_source  \
# 5507      NaN                        Brisbane Courier, 6/21/1886
# 5508      NaN  G. H. Balazs & A. H. Kam; V.M. Coppleson (1958...
#
#                          pdf  \
# 5507   1886.06.17-Lacoon.pdf
# 5508  1886.06.02-Hamakua.pdf
#
#                                                    href
# ...

# %%
# las fechas que solo son año le agregamos junio como mes
df.date=[re.sub(r"\d\d-", "", str(x)) for x in df.date]
df['date_formato'] = [re.search(r"^\d{4}$", str(x))!=None for x in df.date]

for x in range(0,len(df.date)):
    if df['date_formato'][x]==True:
        df["date"][x]="jun-"+str(df.date[x])
# Out:
# <ipython-input-296-d51b4bffa940>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date"][x]="jun-"+str(df.date[x])

# %%
# ya no se necesita 'date_formato', así que se tira
df.drop(columns=['date_formato'], inplace=True)

# %% [markdown]
# ## Fatal

# %%
df['fatal_(y/n)'].unique()
df['fatal_(y/n)']=df['fatal_(y/n)'].str.lower()
df['fatal_(y/n)']=df['fatal_(y/n)'].replace(' n', "n").replace('n ', 'n')

# %%
df['fatal_(y/n)'].unique()
# Out:
# array(['n', 'y', nan, 'unknown', 'f', '#value!'], dtype=object)

# %%
df.loc[(df['fatal_(y/n)'] =="f")|(df['fatal_(y/n)'] =="unknown")|(df['fatal_(y/n)'] =='#value!')] = "nan"
df['fatal_(y/n)']=df['fatal_(y/n)'].replace('n', False).replace('y', True)
df['fatal_(y/n)'] = df['fatal_(y/n)'].astype('bool')
df.rename(columns={'fatal_(y/n)':'fatal'}, inplace=True)

# %%
df['fatal'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ## Name

# %%
df.name=df.name.str.lower()
df.name=df.name.replace("male", "").replace("male x 2", "").replace("5 men", "").replace("m.a.", "").replace("female", "")
df.name=df.name.replace("2 women", "")
set(df.name.unique())
# Out:
# {'',
#  nan,
#  'mark quirt',
#  'brandon taylor',
#  'stanley roser',
#  'an elementary school teacher',
#  'len jones',
#  'walter c. german',
#  'mikado nakamura',
#  'jean-luc majele',
#  'manning samuels',
#  'porfirio lugo camacho ',
#  'arthur e. taylor, a navy diver & member+g1053 of a 24-man demolition team',
#  'toby',
#  'charlie gauzer',
#  'joseph friedlander',
#  'occupant: hasan olta',
#  'verenia keet',
#  'mathieu dasnois',
#  'daniel webb',
#  'leo clarke',
#  'ernest macdonald',
#  'rescue boat of the glenelg surf club, captained by g.w. scarfe',
#  'quassa, a torres strait islander',
#  'taylor trumbauer',
#  'erika hailey',
#  'noel yates',
#  'a native fisherman',
#  'ernest tomson',
#  'percy neale',
#  'somali boatman',
#  'cheryl teague',
#  'andrew morris',
#  'jordon garosalo',
#  'tarara, a male',
#  'jake poland',
#  "21' boat sank. occupants: max butcher, george hardy & peter thorne",
#  'hans vegsund',
#  'hendrie nkwazi',
#  'dave manson',
# ...

# %%
df[df.name=="2 usaf 4-engine planes (an hc-54 & a hc-97) each with 12 onboard collided in mid-air at low altitude and plunged into the atlantic ocean"]
# Out:
#        case_number      date  year          type  country      area  \
# 3452  1964.06.29.a  jun-1964  1964  Sea Disaster  bermuda  Hamilton
#
#                                                location  \
# 3452  2 miles south of Castle Island Harbour entranc...
#
#                                                activity  \
# 3452  conducting a promotional film project for the ...
#
#                                                    name sex_  age  \
# 3452  2 usaf 4-engine planes (an hc-54 & a hc-97) ea...  NaN  NaN
#
#                                                  injury  fatal time species_  \
# 3452  7 rescued, 7 bodies recovered, 10 missing. Man...   True  NaN      NaN
#
#                           investigator_or_source  \
# 3452  Washington Post, 6/30/1964; SAF Case #1295
#
#                                pdf  \
# 3452  1964.06.29-Air-Collision.pdf
#
#                                                    href
# 3452  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
df[df.investigator_or_source.str.startswith("The Advertiser")==True]
# Out:
#        case_number      date  year          type           country  \
# 210     2015.04.25  apr-2015  2015    Unprovoked         australia
# 319   2014.06.18.a  jun-2014  2014    Unprovoked         australia
# 360     2014.02.08  feb-2014  2014    Unprovoked         australia
# 1921    1998.12.22  dec-1998  1998    Unprovoked         australia
# 2033  1997.02.28.b  feb-1997  1997    Unprovoked         australia
# 2034  1997.02.28.a  feb-1997  1997    Unprovoked         australia
# 2041    1997.01.01  jan-1997  1997          Boat         australia
# 2094    1996.02.04  feb-1996  1996    Unprovoked         australia
# 2119    1995.09.11  sep-1995  1995    Unprovoked         australia
# 2426    1989.12.02  dec-1989  1989       Invalid         australia
# 3146  1971.00.00.c  jun-1971  1971    Unprovoked         australia
# 4157  1953.03.19.R  mar-1953  1953    Unprovoked         australia
# 4163    1953.01.20  jan-1953  1953      Provoked         australia
# ...

# %% [markdown]
# ### Time

# %%
df.time.nunique()
# Out:
# 251

# %%
df.time.unique()
# Out:
# array(['13h00', '11h00', '10h43', 'nan', '15h15', '14h30', '15h40',
#        '17h00', '15h00', '14h00', '16h00', '11h30', '12h00', '19h05',
#        '1300', '10h00', '', '22h00', '16h20', '14h34', '15h25', '14h55',
#        '06h00', '17h30', '08h30', '8h00', '15h45', '18h00', '17h46',
#        '13h20', '15h49', '07h00', '08h00', '10h45', '19h00', '13h30',
#        '00h00', '12h30', '10h30', '18h15', '04h00', '14h50', '13h50',
#        '19h20', '10h25', '16h50', '16h45', '15h52', '07h30', '06h15',
#        '14h40', '19h45', '17h10', '15h30', '10h10', '08h45', '20h00',
#        '09h00', '12h10', '18h05', '19h30', '11h41', '12h25', '09h30',
#        '17h51', '16h12', '12h45', '10h50', '13h45', '14h15', '16h30',
#        '09h45', '11h45', '10h20', '18h30', '06h45', '05h00', '03h30',
#        '06h30', '11h15', '17h20', '18h45', '16h40', '16h18', '11h10',
#        '17h50', '17h01', '10h15', '09h57', '08h20', '17h58', '20h30',
# ...

# %%
df.time=df.time.str.lower()

# %%
df.time=[re.sub(r'late afternoon|just before sundown|mid afternoon|before daybreak|sunset', "17h00", str(x)) for x in df.time]
df.time=[re.sub(r'after noon|afternoon|early afternoon|after lunch', "14h00", str(x)) for x in df.time]
df.time=[re.sub(r'morning|early morning|daybreak|dawn','8h00', str(x)) for x in df.time]
df.time=[re.sub(r'midnight', "00h00", str(x)) for x in df.time]
df.time=[re.sub(r'evening|after dark|early evening|nightfall', "20h00", str(x)) for x in df.time]
df.time=[re.sub(r'noon|just before noon|midday|lunchtime|late morning', "12h00", str(x)) for x in df.time]
df.time=[re.sub(r'late night', "23h00", str(x)) for x in df.time]
##"2 hrs before sunset"|"shortly before dusk" sometime between 06h00 & 08hoo | between 06h00 & 
df.time=[re.sub(r'daytime|just before |>|after |<|\"|x|j|', "", str(x)) for x in df.time]
df.time=[re.sub(r'dark|p.m.|� |am|500|a.m.|night|mid|   ', "", str(x)) for x in df.time]
df.time=[re.sub(r' \/.*|--.*|-.*|\w+ .*', "", str(x)) for x in df.time]
df.time=df.time.replace("dusk", "02h00")
df.time=df.time.replace("830", "")
