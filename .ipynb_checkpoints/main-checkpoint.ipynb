# %%
import pandas as pd
import numpy as np
import re

# %%
path='data/attacks.csv'

# %%
shark = pd.read_csv(path, encoding='latin-1')

# %%
#shark.head(5)

# %%
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
shark.shape
# Out:
# (25723, 24)

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark.columns = shark.columns.str.strip()

# %%
shark.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#shark[shark['Case Number'].isnull()]

# %%
shark.drop(
shark[shark['Case Number'].isnull()].index,
inplace=True    
)

# %%
#shark.shape

# %%
#shark[shark['Date'].isnull()]

# %%
shark.drop(
shark[shark['Date'].isnull()].index,
inplace=True    
)

# %%
#shark.isnull().sum()

# %%
#shark = shark.drop(['Year'], axis=1)

# %%
len(shark)
# Out:
# 6301

# %%
shark.Date[0]
# Out:
# '25-Jun-2018'

# %%
#shark.head(20)

# %%
# dates = []

# for i in range(len(shark)):
#     x = re.findall(r'\d+\-\w+\-\d+', shark.Date[i])
#     if len(x) > 0:
#         y = x[0]
#         dates.append(y)
    
#        if x[0] in shark.Date[i]:
#            dates.append(x[0])

# %%
# only_dates = shark.Date.apply(lambda x: re.findall(r'\d+\-\w+\-\d+',x))
# if only_

# %%
# reported = shark.Date.apply(lambda x: re.findall(r'Reported ',x)).index
# len(reported)

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6300 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6300 non-null   object
#  1   Date                    6300 non-null   object
#  2   Year                    6299 non-null   float64
#  3   Type                    6296 non-null   object
#  4   Country                 6250 non-null   object
#  5   Area                    5845 non-null   object
#  6   Location                5760 non-null   object
#  7   Activity                5756 non-null   object
#  8   Name                    6090 non-null   object
#  9   Sex                     5735 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6272 non-null   object
#  12  Fatal (Y/N)             5761 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
shark.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2830
# Injury                      28
# Fatal (Y/N)                539
# Time                      3353
# Species                   2837
# Investigator or Source      17
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6300
# Unnamed: 23               6299
# dtype: int64

# %%
shark.Year
# Out:
# 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 6301, dtype: float64

# %%
pd.to_numeric(shark.Year)
# Out:
# 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 6300, dtype: float64

# %%
shark
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
rows_to_remove = shark[shark.index == 6079].index

# %%
rows_to_remove
# Out:
# Int64Index([6079], dtype='int64')

# %%
df_conteo_limpio = df_conteo.drop(rows_to_remove, axis=0)

# %%
shark.drop(rows_to_remove, axis=0, inplace = True)

# %%
shark[shark.Year.isnull()]
# Out:
#       Case Number                  Date  Year     Type    Country        Area  \
# 187  2017.01.08.R  Reported 08-Jan-2017   NaN  Invalid  AUSTRALIA  Queensland
#
#     Location      Activity          Name Sex  ...     Species  \
# 187      NaN  Spearfishing  Kerry Daniel   M  ...  Bull shark
#
#      Investigator or Source                           pdf  \
# 187  Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
#
#                                           href formula  \
# 187  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 187  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
#
#     Case Number.2 original order Unnamed: 22 Unnamed: 23
# 187  2017.01.08.R         6116.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
shark.info()

# %%
shark['original order'] = shark['original order'].astype(str)

# %%
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6300 entries, 0 to 6301
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6300 non-null   object
#  1   Date                    6300 non-null   object
#  2   Type                    6296 non-null   object
#  3   Country                 6250 non-null   object
#  4   Area                    5845 non-null   object
#  5   Location                5760 non-null   object
#  6   Activity                5756 non-null   object
#  7   Name                    6090 non-null   object
#  8   Sex                     5735 non-null   object
#  9   Age                     3471 non-null   object
#  10  Injury                  6272 non-null   object
#  11  Fatal (Y/N)             5761 non-null   object
#  12  Time                    2948 non-null   object
#  13  Species                 3464 non-null   object
# ...

# %%
shark.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2829
# Injury                      28
# Fatal (Y/N)                539
# Time                      3352
# Species                   2836
# Investigator or Source      17
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6299
# Unnamed: 23               6298
# dtype: int64

# %%
len(shark)
# Out:
# 6300

# %%
df = shark.copy()

# %%
df.head()
# Out:
#   Case Number         Date        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11  ...
# 2                    Habush, Oahu      Surfing      John Denges   M   48  ...
# 3              Arrawarra Headland      Surfing             male   M  NaN  ...
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN  ...
#
#            Species          Investigator or Source                       pdf  \
# ...

# %%
# Out:
# ['25', '2018']
