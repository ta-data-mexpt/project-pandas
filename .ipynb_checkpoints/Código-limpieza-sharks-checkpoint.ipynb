# %%
import pandas as pd

# %%
df = pd.read_csv('attacks.csv', encoding='iso-8859-1')

# %%
df.head(2)
# Out:
#   Case Number         Date    Year        Type Country        Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating     USA  California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  ...
#
#       Species           Investigator or Source                     pdf  \
# 0  White shark                R. Collier, GSAF    2018.06.25-Wolfe.pdf
# 1          NaN  K.McMurray, TrackingSharks.com  2018.06.18-McNeely.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...

# %%
df.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df['Unnamed: 22'].isnull().sum()
# Out:
# 25722

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.drop(columns = ['Unnamed: 22', 'Unnamed: 23'], inplace = True)

# %%
df.head(2)
# Out:
#   Case Number         Date    Year        Type Country        Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating     USA  California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  ...
#
#   Fatal (Y/N)           Time     Species           Investigator or Source  \
# 0           N          18h00  White shark                R. Collier, GSAF
# 1           N  14h00  -15h00          NaN  K.McMurray, TrackingSharks.com
#
#                       pdf                                       href formula  \
# 0    2018.06.25-Wolfe.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  2018.06.18-McNeely.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# ...

# %%
df.describe(include='all').T
# Out:
#                          count unique  \
# Case Number               8702   6287
# Date                      6302   5433
# Year                    6300.0    NaN
# Type                      6298      8
# Country                   6252    212
# Area                      5847    825
# Location                  5762   4108
# Activity                  5758   1532
# Name                      6092   5230
# Sex                       5737      6
# Age                       3471    157
# Injury                    6274   3737
# Fatal (Y/N)               5763      8
# Time                      2948    366
# Species                   3464   1549
# Investigator or Source    6285   4969
# pdf                       6302   6291
# href formula              6301   6290
# href                      6302   6285
# Case Number.1             6302   6285
# Case Number.2             6302   6286
# original order          6309.0    NaN
#
# ...

# %%
df.columns = df.columns.str.lower().str.replace('[ .]','_', regex=True)

# %%
df.columns = df.columns.str.replace('_$','',regex=True)

# %%
#Se eliminan los espacios y se reemplazan por '_', algunas palabras quedaron con _al final, por lo que se eliminaron
df.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal_(y/n)', 'time',
#        'species', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number_1', 'case_number_2', 'original_order'],
#       dtype='object')

# %%
nulos = df.isnull().sum()
nulos
# Out:
# case_number               17021
# date                      19421
# year                      19423
# type                      19425
# country                   19471
# area                      19876
# location                  19961
# activity                  19965
# name                      19631
# sex                       19986
# age                       22252
# injury                    19449
# fatal_(y/n)               19960
# time                      22775
# species                   22259
# investigator_or_source    19438
# pdf                       19421
# href_formula              19422
# href                      19421
# case_number_1             19421
# case_number_2             19421
# original_order            19414
# dtype: int64

# %%
df.shape
# Out:
# (25723, 22)

# %%
df.dropna(how='all', inplace=True)
#elimino los renglones donde faltan todos los valores

# %%
df.shape
# Out:
# (8703, 22)

# %%
nulos_df = df.isnull().sum()
nulos_df
# Out:
# case_number                  1
# date                      2401
# year                      2403
# type                      2405
# country                   2451
# area                      2856
# location                  2941
# activity                  2945
# name                      2611
# sex                       2966
# age                       5232
# injury                    2429
# fatal_(y/n)               2940
# time                      5755
# species                   5239
# investigator_or_source    2418
# pdf                       2401
# href_formula              2402
# href                      2401
# case_number_1             2401
# case_number_2             2401
# original_order            2394
# dtype: int64

# %%
porcentaje_nulos = nulos_df/df.shape[0]
porcentaje_nulos.sort_values()
# Out:
# case_number               0.000115
# original_order            0.275078
# case_number_1             0.275882
# href                      0.275882
# pdf                       0.275882
# date                      0.275882
# case_number_2             0.275882
# href_formula              0.275997
# year                      0.276112
# type                      0.276341
# investigator_or_source    0.277835
# injury                    0.279099
# country                   0.281627
# name                      0.300011
# area                      0.328163
# fatal_(y/n)               0.337815
# location                  0.337929
# activity                  0.338389
# sex                       0.340802
# age                       0.601172
# species                   0.601976
# time                      0.661266
# dtype: float64

# %%
df[df.case_number.isnull()].index.tolist()
# Out:
# [5488]

# %%
case_number_cero = df[df.case_number == '0'].index.tolist()

# %%
df.loc[case_number_cero]
# Out:
#      case_number date  year type country area location activity name  sex  \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 8697           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... fatal_(y/n) time species investigator_or_source  pdf href_formula  \
# ...

# %%
df[(df.case_number == '0') & (df.activity.isnull().sum() == '0')]
#Todos los renglones con case_number = 0 tienen valores nulos
# Out:
# Empty DataFrame
# Columns: [case_number, date, year, type, country, area, location, activity, name, sex, age, injury, fatal_(y/n), time, species, investigator_or_source, pdf, href_formula, href, case_number_1, case_number_2, original_order]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.drop(df.loc[df.case_number == '0'].index, inplace = True)

# %%
df.drop(df.loc[df.case_number == 'xx'].index, inplace = True)

# %%
df.describe(include='all').T
# Out:
#                          count unique  \
# case_number               6301   6285
# date                      6302   5433
# year                    6300.0    NaN
# type                      6298      8
# country                   6252    212
# area                      5847    825
# location                  5762   4108
# activity                  5758   1532
# name                      6092   5230
# sex                       5737      6
# age                       3471    157
# injury                    6274   3737
# fatal_(y/n)               5763      8
# time                      2948    366
# species                   3464   1549
# investigator_or_source    6285   4969
# pdf                       6302   6291
# href_formula              6301   6290
# href                      6302   6285
# case_number_1             6302   6285
# case_number_2             6302   6286
# original_order          6302.0    NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             6301 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex                     5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_(y/n)             5763 non-null   object
#  13  time                    2948 non-null   object
# ...

# %%
df.dtypes
# Out:
# case_number                object
# date                       object
# year                      float64
# type                       object
# country                    object
# area                       object
# location                   object
# activity                   object
# name                       object
# sex                        object
# age                        object
# injury                     object
# fatal_(y/n)                object
# time                       object
# species                    object
# investigator_or_source     object
# pdf                        object
# href_formula               object
# href                       object
# case_number_1              object
# case_number_2              object
# original_order            float64
# dtype: object

# %%
df[df.type.isnull()]
# Out:
#        case_number                  date    year type    country  \
# 85    2017.09.15.a           15-Sep-2017  2017.0  NaN      SAMOA
# 382     2015.07.27           27-Jul-2015  2015.0  NaN  AUSTRALIA
# 4867  1936.09.11.R  Reported 11-Sep-1936  1936.0  NaN    VIETNAM
# 5705  1890.03.03.R  Reported 03-Mar-1890  1890.0  NaN     CEYLON
#
#                area          location           activity           name sex  \
# 85     Upolu Island         Nofoalii            Fishing           male   M
# 382        Victoria  Tyrendarra Beach            Surfing           male   M
# 4867            NaN            Saigon  Wreck of a sampam         8 crew   M
# 5705            NaN               NaN             Diving  a pearl diver   M
#
#       ... fatal_(y/n)   time species            investigator_or_source  \
# 85    ...           N  Night     NaN         Samoa Observer, 9/16/2017
# 382   ...         NaN    NaN     NaN                               NaN
# ...

# %%
df.type.value_counts(dropna=False)
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# NaN                4
# Questionable       2
# Boatomg            1
# Name: type, dtype: int64

# %%
df.type = df.type.replace({'Boat':'Boating', 'Boatomg':'Boating', 'Questionable':'Invalid'})

# %%
df.type.fillna('Invalid', inplace = True)

# %%
df.type.value_counts(dropna=False)
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          553
# Boating          341
# Sea Disaster     239
# Name: type, dtype: int64

# %%
#No me funionó esta funcion, si los nombres no estaban en nombres_def, devuelve NONE
#nombres_def = {'Boating':['Boat','Boatomg'], 'Invalid':'Questionable'}
#def correcion(x):
#    try:
#        correcciones = [key for key,val in nombres_def.items() if x in val]
#        if correcciones[0] != None:
#            return correcciones[0]
#        else:
#            return x
#    except:
#        print(x)

# %%
#correcion('Boating')

# %%
df.country = df.country.str.upper()

# %%
df.country.isnull().sum()
# Out:
# 50

# %%
df.loc[df[df.country.isnull()].index][['country', 'area', 'location']]
# Out:
#      country                                           area  \
# 62       NaN                                            NaN
# 525      NaN                                            NaN
# 2956     NaN                                English Channel
# 3378     NaN                                            NaN
# 3387     NaN                                  Caribbean Sea
# 3388     NaN                                            NaN
# 3395     NaN                                            NaN
# 3399     NaN                                            NaN
# 3425     NaN                                            NaN
# 3605     NaN                                            NaN
# 3661     NaN                                            NaN
# 4018     NaN              Between Timor & Darwin, Australia
# 4231     NaN             Near the Andaman & Nicobar Islands
# 4266     NaN                   Between Comores & Madagascar
# 4498     NaN                                  Caribbean Sea
# ...

# %%
df.country = df.country.fillna('Unnown')

# %%
df.country.isnull().sum()
# Out:
# 0

# %%
nulos = df.isnull().sum()
nulos
porcentaje_nulos = nulos/df.shape[0]
porcentaje_nulos
# Out:
# case_number               0.000159
# date                      0.000000
# year                      0.000317
# type                      0.000000
# country                   0.000000
# area                      0.072199
# location                  0.085687
# activity                  0.086322
# name                      0.033323
# sex                       0.089654
# age                       0.449222
# injury                    0.004443
# fatal_(y/n)               0.085528
# time                      0.532212
# species                   0.450333
# investigator_or_source    0.002698
# pdf                       0.000000
# href_formula              0.000159
# href                      0.000000
# case_number_1             0.000000
# case_number_2             0.000000
# original_order            0.000000
# dtype: float64

# %%
df.tail()
# Out:
#      case_number         date  year        type             country  \
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ... fatal_(y/n) time species  \
# ...

# %%
#eliminar area y locations??
#df.drop(columns = ['area', 'location'])

# %%
df.activity.value_counts(dropna=False)
# Out:
# Surfing                                   971
# Swimming                                  869
# NaN                                       544
# Fishing                                   431
# Spearfishing                              333
#                                          ...
# Playing with a frisbee in the shallows      1
# Sinking of the ferryboat Dumaguete          1
# Wreck of the Storm King                     1
# Feeding mullet to sharks                    1
# Wreck of  large double sailing canoe        1
# Name: activity, Length: 1533, dtype: int64

# %%
df.groupby('activity').filter(lambda x: len(x) == 1)
# Out:
#        case_number                  date    year          type       country  \
# 24      2018.04.22           22-Apr-2018  2018.0    Unprovoked  SOUTH AFRICA
# 41      2018.02.17           18-Feb-2018  2018.0      Provoked     AUSTRALIA
# 55      2017.12.21           21-Dec-2017  2017.0      Provoked      MALAYSIA
# 59    2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster         LIBYA
# 64      2017.11.04           04-Nov-2017  2017.0    Unprovoked          CUBA
# ...            ...                   ...     ...           ...           ...
# 6281       ND.0021               No date     0.0    Unprovoked  SOUTH AFRICA
# 6284       ND.0018           Before 1911     0.0    Unprovoked       VIETNAM
# 6285       ND.0017           Before 1921     0.0    Unprovoked  SOUTH AFRICA
# 6286       ND.0016           Before 1921     0.0    Unprovoked  SOUTH AFRICA
# 6287       ND.0015           Before 1917     0.0    Unprovoked          FIJI
#
# ...

# %%
df.age.unique()
# Out:
# array(['57', '11', '48', nan, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
# ...

# %%
df.age.replace({'7      &    31': '7,31', '25 to 35': '30', "60's": '60', ' 28':'28', '2 to 3 months': '< 1', '36 & 26':'26,36', '21 & ?':'21','46 & 34': '46,34', '\xa0 ':'unknown', 'F':'unknown', 'mid-30s':'30', 'adult':'30', '18 or 20':'20', '23 & 26': '23, 26', '60s':'60', '23 & 20': '23, 20', 'mid-20s':'25', '25 or 28':'25', '13 or 14':'15','32 & 30':'32,30', '(adult)':'30', '17 & 16':'17,26', '30 & 32':'30,32', '20?':'20', '?    &   14':'14', "middle-age":'40', 'Elderly':'60', '31 or 33':'30', '50 & 30':'50, 30', '  ':'unknown', '30 or 36':'30', ' 30':'30', '9 & 12':'9, 12', 'A.M.':'unknown', 'Both 11':'11', '2½':'2', '18 months':'1', '>50':'50', '34 & 19':'34, 19', '33 & 37':'33, 37', '16 to 18':'18', '33 & 26':'33, 26', 'Ca. 33':'33', '? & 19':'19', '21 or 26':'25', '13 or 18':'15', '10 or 12':'10', ' 43':'43', '6½':'6', 'MAKE LINE GREEN':'unknown', 'Teens':'15', '28 & 26':'28, 26', '17 & 35':'17, 35', '20 ':'20', '74 ':'74','21, 34, 24 & 35':'21, 34, 24, 35', '28, 23 & 30': '28, 23, 30', '33 or 37': '35', 'X':'unknown', '9 or 10':'10', '12 or 13':'12', '9 months':'<1','"young"':'15', '37, 67, 35, 27,  ? & 27':'37, 67, 35, 27, 27', '36 & 23':'36, 23', '18 to 22': '20', '45 ':'45'})
# Out:
# 0        57
# 1        11
# 2        48
# 3       NaN
# 4       NaN
#        ...
# 6297    NaN
# 6298    NaN
# 6299    NaN
# 6300    NaN
# 6301     15
# Name: age, Length: 6302, dtype: object

# %%
lista

# %%
df.isnull().sum()
# Out:
# case_number                  1
# date                         0
# year                         2
# type                         0
# country                      0
# area                       455
# location                   540
# activity                   544
# name                       210
# sex                        565
# age                       2831
# injury                      28
# fatal_(y/n)                539
# time                      3354
# species                   2838
# investigator_or_source      17
# pdf                          0
# href_formula                 1
# href                         0
# case_number_1                0
# case_number_2                0
# original_order               0
# dtype: int64

# %%
df.date.unique()
# Out:
# array(['25-Jun-2018', '18-Jun-2018', '09-Jun-2018', ..., '1883-1889',
#        '1845-1853', nan], dtype=object)

# %%
df.date[df.date=='1883-1889']
# Out:
# 6300    1883-1889
# Name: date, dtype: object

# %%
df.loc[[6300]]
# Out:
#      case_number       date  year        type country area  \
# 6300     ND.0002  1883-1889   0.0  Unprovoked  PANAMA  NaN
#
#                   location activity             name sex  ... fatal_(y/n)  \
# 6300  Panama Bay 8ºN, 79ºW      NaN  Jules Patterson   M  ...           Y
#
#      time species investigator_or_source                         pdf  \
# 6300  NaN     NaN    The Sun, 10/20/1938  ND-0002-JulesPatterson.pdf
#
#                                            href_formula  \
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number_1  \
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
#
#      case_number_2 original_order
# 6300       ND.0002            3.0
#
# [1 rows x 22 columns]
