# %%
import pandas as pd
import re

# %%
# Tuve un problema a la hora leer el csv de la data, el cual fue:
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 1: invalid start byte
# asi que tuve que ocupar una codifciación diferente
data = pd.read_csv('GSAF5.csv', encoding = "ISO-8859-1")

# %%
data
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
# primero obtenemos los headers de las columnas actuales
columns = data.columns
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# analizando el csv, eliminamos las columnas con información duplicada
# se observa también que hay dos columnas inservible, además de la columna 
# de pdf ya que ese nombre de pdf puede ser consultado en la URL
data = data.drop(['href','Case Number.2','Unnamed: 22','Unnamed: 23','pdf'], axis = 1)

# %%
data
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
# Vamos a renombrar para que sea más fácil el etendimiento de la columna
data = data.rename(columns={'href formula':'URL of PDF',
                            'Displacement':'Engine Displacement',
                            'Sex ':'Sex',
                           'Fatal (Y/N)':'Fatal (Y/N/Unknown)',
                           'Species ':'Species',
                           'original order':'Original Order'})

# %%
# Vamos a reordenar las columnas
column_order = ['Original Order','Case Number.1','Case Number','Date','Year','Time',
               'Country','Area','Location','Name','Age','Sex','Activity','Type',
                'Injury','Fatal (Y/N/Unknown)','Species','Investigator or Source','URL of PDF']

# %%
data = data[column_order]
data
# Out:
#       Original Order Case Number.1   Case Number         Date  Year   Time  \
# 0               5993  2016.09.18.c  2016.09.18.c    18-Sep-16  2016  13h00
# 1               5992  2016.09.18.b  2016.09.18.b    18-Sep-16  2016  11h00
# 2               5991  2016.09.18.a  2016.09.18.a    18-Sep-16  2016  10h43
# 3               5990    2016.09.17    2016.09.17    17-Sep-16  2016    NaN
# 4               5989    2016.09.16    2016.09.15    16-Sep-16  2016    NaN
# ...              ...           ...           ...          ...   ...    ...
# 5987               6       ND.0005       ND.0005  Before 1903     0    NaN
# 5988               5       ND.0004       ND.0004  Before 1903     0    NaN
# 5989               4       ND.0003       ND.0003    1900-1905     0    NaN
# 5990               3       ND.0002       ND.0002    1883-1889     0    NaN
# 5991               2       ND.0001       ND.0001    1845-1853     0    NaN
#
#                  Country               Area  \
# ...

# %%
# vamos a limpiar la columna de 'Date', quitamos la cadena 'Reported ' para dejar unicamente la fecha
data['Date'] = [x.replace('Reported', '') for x in data['Date']]

# %%
# Quitaremos los espacios en blanco con los que empiezan en 'Date'
data['Date'] = [x.lstrip() for x in data['Date']]

# %%
# Quitaremos los espacios en blanco con los que empiezan en 'Date'
data['Date'] = [x.lstrip() for x in data['Date']]

# %%
# En columna 'Fatal (Y/N)' reemplazaremos valores en blanco o desconocidos
# Intente meter un if para cualqueri valro diferente a 'Y' o 'N' coloque un 'UNKNOW' pero no lo logré
data['Fatal (Y/N/Unknown)'] = data['Fatal (Y/N/Unknown)'].str.replace('F','UNKNOW')

# %%
data['Fatal (Y/N/Unknown)'] = data['Fatal (Y/N/Unknown)'].str.replace(' ','UNKNOW')

# %%
data['Fatal (Y/N/Unknown)'] = data['Fatal (Y/N/Unknown)'].str.replace('#VALUE!','UNKNOW')

# %%
data
# Out:
#       Original Order Case Number.1   Case Number         Date  Year   Time  \
# 0               5993  2016.09.18.c  2016.09.18.c    18-Sep-16  2016  13h00
# 1               5992  2016.09.18.b  2016.09.18.b    18-Sep-16  2016  11h00
# 2               5991  2016.09.18.a  2016.09.18.a    18-Sep-16  2016  10h43
# 3               5990    2016.09.17    2016.09.17    17-Sep-16  2016    NaN
# 4               5989    2016.09.16    2016.09.15    16-Sep-16  2016    NaN
# ...              ...           ...           ...          ...   ...    ...
# 5987               6       ND.0005       ND.0005  Before 1903     0    NaN
# 5988               5       ND.0004       ND.0004  Before 1903     0    NaN
# 5989               4       ND.0003       ND.0003    1900-1905     0    NaN
# 5990               3       ND.0002       ND.0002    1883-1889     0    NaN
# 5991               2       ND.0001       ND.0001    1845-1853     0    NaN
#
#                  Country               Area  \
# ...

# %%
# Trabajaremos con la columna 'Time'

# %%
data['Time'] = data['Time'].str.replace(' ',' UNKNOW')

# %%
data.dtypes
# Out:
# Original Order             int64
# Case Number.1             object
# Case Number               object
# Date                      object
# Year                       int64
# Time                      object
# Country                   object
# Area                      object
# Location                  object
# Name                      object
# Age                       object
# Sex                       object
# Activity                  object
# Type                      object
# Injury                    object
# Fatal (Y/N/Unknown)       object
# Species                   object
# Investigator or Source    object
# URL of PDF                object
# dtype: object

# %%
data = data.drop(['Time_extract'], axis = 1)

# %%
data['Time'] = data['Time'].str.replace('""','')

# %%
data['Time'] = data['Time'].str.replace('>','')

# %%
data['Time'] = data['Time'].str.replace('h',':')

# %%
# Se extraen los números de 'Time' para ponerlos en una nueva columna
data['Time_extract'] = data['Time'].str.extract('(\d+:\d+)')
#data

# %%
# Tratar de encontrar los nombres, todavía se debe perfecionar
data['Name_extract'] = data['Name'].str.extract('([A-Z][a-z]+.[A-Z][a-z]+)')
data
# Out:
#       Original Order Case Number.1   Case Number         Date  Year   Time  \
# 0               5993  2016.09.18.c  2016.09.18.c    18-Sep-16  2016  13:00
# 1               5992  2016.09.18.b  2016.09.18.b    18-Sep-16  2016  11:00
# 2               5991  2016.09.18.a  2016.09.18.a    18-Sep-16  2016  10:43
# 3               5990    2016.09.17    2016.09.17    17-Sep-16  2016    NaN
# 4               5989    2016.09.16    2016.09.15    16-Sep-16  2016    NaN
# ...              ...           ...           ...          ...   ...    ...
# 5987               6       ND.0005       ND.0005  Before 1903     0    NaN
# 5988               5       ND.0004       ND.0004  Before 1903     0    NaN
# 5989               4       ND.0003       ND.0003    1900-1905     0    NaN
# 5990               3       ND.0002       ND.0002    1883-1889     0    NaN
# 5991               2       ND.0001       ND.0001    1845-1853     0    NaN
#
#                  Country               Area  \
# ...

# %%
#data

# %%
#Trabajaremos con al columna 'Age'
data['Age_extract'] = data['Age'].str.extract('(\d+)')
data
# Out:
#       Original Order Case Number.1   Case Number         Date  Year   Time  \
# 0               5993  2016.09.18.c  2016.09.18.c    18-Sep-16  2016  13:00
# 1               5992  2016.09.18.b  2016.09.18.b    18-Sep-16  2016  11:00
# 2               5991  2016.09.18.a  2016.09.18.a    18-Sep-16  2016  10:43
# 3               5990    2016.09.17    2016.09.17    17-Sep-16  2016    NaN
# 4               5989    2016.09.16    2016.09.15    16-Sep-16  2016    NaN
# ...              ...           ...           ...          ...   ...    ...
# 5987               6       ND.0005       ND.0005  Before 1903     0    NaN
# 5988               5       ND.0004       ND.0004  Before 1903     0    NaN
# 5989               4       ND.0003       ND.0003    1900-1905     0    NaN
# 5990               3       ND.0002       ND.0002    1883-1889     0    NaN
# 5991               2       ND.0001       ND.0001    1845-1853     0    NaN
#
#                  Country               Area  \
# ...

# %%
data.to_csv('tiburoncinattack.csv')

# %%
for x in data['Date']:
    print(x)
