# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse
from datetime import datetime
from datetime import date
import re

# %%
mess = pd.read_csv('C:/Users/joavi/Documents/project-pandas/GSAF5.csv',encoding ='unicode_escape')
mess.head(1)
# Out:
#     Case Number       Date  Year        Type Country     Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked     USA  Florida
#
#                            Location Activity  Name Sex   ... Species   \
# 0  New Smyrna Beach, Volusia County  Surfing  male    M  ...      NaN
#
#         Investigator or Source                   pdf  \
# 0  Orlando Sentinel, 9/19/2016  2016.09.18.c-NSB.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
#
# [1 rows x 24 columns]

# %%
columna=[]
for colu in mess.columns:
    columna.append(colu.strip())
#print(columna)
mess.columns = columna

# %%
mess.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
try:
    
    #mess['Date'] = mess['Date'].apply(lambda x: re.sub('.*', 'why2', x))
    #mess['Date'] = mess['Date'].apply(lambda x: re.sub('.*', 'works', x))
#     mess['Date'] = mess['Date'].apply(lambda x: re.sub('[\'','', x))
#     mess['Date'] = mess['Date'].apply(lambda x: re.sub('\']','', x))
#     mess['Date'] = mess['Date'].apply(lambda x: parse(x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Reported in ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Reported in ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Reported ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Reportd ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Summer of ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Ca. ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Ca . ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Circa ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Circa ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Between ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Before ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('No date, ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Summer ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Winter ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Fall ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Autumn ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Late ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Early ', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Mid-', '', x))
    mess['Date'] = mess['Date'].apply(lambda x: re.sub('Mid ', '', x))
    #mess['Date'] = mess['Date'].apply(lambda x: re.sub('', '', x))
    mess['Date'] = mess['Date'].map(lambda txt: (lambda x: re.search(r'\d{1,2}.\w{2,3}.\d{1,4}', x).group()
                                                 if re.search(r'\d{1,2}.\w{2,3}.\d{1,4}',x) else (re.search(r'\d{2,4}',x).group() 
                                                                                                if re.search(r'\d{2,4}',x) else x))(txt))
    
except:
    pass

try:
    mess['Date'] = mess['Date'].apply(lambda x: x.strip())
    mess['Date'] = mess['Date'].apply(lambda x: parse(x))
    
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%m-%d-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%d-%m-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%d-%b-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%d-%B-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%d-%b-%Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%d-%B-%Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%-d-%m-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%-d-%b-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%-d-%B-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%-d-%b-%Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%-d-%B-%Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%b-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%b-%Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%B-%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%B %Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%b %y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%b %Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%B %y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%B %Y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%y'))
#     mess['Date'] = mess['Date'].apply(lambda x: datetime.strptime(x['Date'], '%Y'))
except:
    pass

for ind in mess.index:
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%m-%d-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%y-%m-%d').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%Y-%m-%-d').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%Y-%m-%d').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%m-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%b-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%B-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%b-%Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%B-%Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%-d-%m-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%-d-%b-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%-d-%B-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%-d-%b-%Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%-d-%B-%Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%b-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%b-%Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%B-%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%B-%Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%b %y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%b %Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%B %y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%B %Y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%y').date()
    except:
        pass
    try:
        mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%Y').date()
    except:
        pass
#mess.to_csv('CleanData.csv')
# Out:
# <ipython-input-646-4c61d8388da2>:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%b-%y').date()
# <ipython-input-646-4c61d8388da2>:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mess['Date'][ind] = datetime.strptime(mess['Date'][ind], '%d-%b-%Y').date()
# <ipython-input-646-4c61d8388da2>:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
try:
    mess['Type'] = mess['Type'].apply(lambda x: re.sub('Boating', 'Boat', x))
except:
    pass

# %%
mess['Country'] = mess['Country'].map(lambda x: re.sub(r'\W+', '', str(x)))
mess['Country'] = mess['Country'].map(lambda x: re.sub(r'\(.*\)', '', str(x)).strip())

# %%
#re.findall('[A-Z]\w+\s[A-Z]\w+',text)
#mess['Name'].apply(lambda x: re.search(r'[A-Z]\w+\s[A-Z]\w+', x).group() if re.search(r'[A-Z]\w+\s[A-Z]\w+', x) else x)
try:
    mess['Name'] = mess['Name'].apply(lambda x: re.search(r'[A-Z]\w+\s[A-Z]\w+', x).group())
except:
    pass
try:
    mess['Name'] = mess['Name'].apply(lambda x: re.search(r'[Aa-Zz]\w+\s[Aa-Zz]\w+', x).group())
except:
    pass

# %%
# mess['Sex'] = mess['Sex'].apply(lambda x: str(x).strip())
# mess['Sex'] = mess['Sex'].apply(lambda x: re.sub('M', 'Male', str(x)))
# mess['Sex'] = mess['Sex'].apply(lambda x: re.sub('F', 'Female', str(x)))
# mess['Sex'] = mess['Sex'].apply(lambda x: re.sub('N', '', str(x)))
# mess['Sex'] = mess['Sex'].apply(lambda x: re.sub('lli', '', str(x)))
# mess['Sex'] = mess['Sex'].apply(lambda x: re.sub('\.', '', str(x)))
mess['Sex'] = mess['Sex'].map(lambda x: re.search(r'M|F',str(x)).group() if re.search(r'M|F',str(x)) else 'Unknown')
#mess['Sex'] = mess['Sex'].apply(lambda x: re.sub('', '', str(x)))

# %%
mess['Age'] = mess['Age'].map(lambda x: re.search(r'\d{1,2}',str(x)).group() if re.search(r'\d{1,2}',str(x)) else 'Unknown')

# %%
mess['Fatal (Y/N)'] = mess['Fatal (Y/N)'].map(lambda x: re.search(r'Y|N',str(x)).group() if re.search(r'Y|N',str(x)) else 'Unknown')

# %%
mess['Time'] = mess['Time'].map(lambda x: (lambda x: re.search(r'\d{2}(h|j)\d{2}',str(x)).group() if re.search(r'\d{2}(h|j)\d{2}',str(x)) else 'Unknown')(x))
mess['Time'] = mess['Time'].apply(lambda x: re.sub('h|j', ':', x))
for tiem in mess.index:
    try:
        mess['Time'][tiem] = datetime.strptime(mess['Time'][tiem], '%H:%M').time()
    except:
        pass
# Out:
# <ipython-input-653-63c44a223ebb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mess['Time'][tiem] = datetime.strptime(mess['Time'][tiem], '%H:%M').time()

# %%
mess.to_csv('CleanData.csv')
